# %%
import pandas as pd

# %%
glass_data = pd.read_csv('glass.data')

# %%
glass_data
# Out:
#      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
# converting a dataframe to a list of dictionaries of the records
glass_dict = glass_data.to_dict(orient='records')

# %%
type(glass_dict)
# Out:
# list

# %%
import pprint
printer = pprint.PrettyPrinter()

# %%
# for i in glass_dict:
#     printer.pprint(i)
# Out:
# {'Al': 1.1,
#  'Ba': 0.0,
#  'Ca': 8.75,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 4.49,
#  'Na': 13.64,
#  'RI': 1.52101,
#  'Si': 71.78,
#  'index': 1}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 7.83,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.48,
#  'Mg': 3.6,
#  'Na': 13.89,
#  'RI': 1.5176100000000001,
#  'Si': 72.73,
#  'index': 2}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.78,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.39,
#  'Mg': 3.55,
#  'Na': 13.53,
#  'RI': 1.5161799999999999,
#  'Si': 72.99,
#  'index': 3}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 8.22,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.69,
#  'Na': 13.21,
#  'RI': 1.51766,
#  'Si': 72.61,
#  'index': 4}
# {'Al': 1.24,
#  'Ba': 0.0,
#  'Ca': 8.07,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 3.62,
#  'Na': 13.27,
#  'RI': 1.51742,
#  'Si': 73.08,
#  'index': 5}
# {'Al': 1.62,
#  'Ba': 0.0,
#  'Ca': 8.07,
#  'Class': 1,
#  'Fe': 0.26,
#  'K': 0.64,
#  'Mg': 3.61,
#  'Na': 12.79,
#  'RI': 1.51596,
#  'Si': 72.97,
#  'index': 6}
# {'Al': 1.14,
#  'Ba': 0.0,
#  'Ca': 8.17,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.6,
#  'Na': 13.3,
#  'RI': 1.5174299999999998,
#  'Si': 73.09,
#  'index': 7}
# {'Al': 1.05,
#  'Ba': 0.0,
#  'Ca': 8.24,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.61,
#  'Na': 13.15,
#  'RI': 1.51756,
#  'Si': 73.24,
#  'index': 8}
# {'Al': 1.37,
#  'Ba': 0.0,
#  'Ca': 8.3,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.58,
#  'Na': 14.04,
#  'RI': 1.51918,
#  'Si': 72.08,
#  'index': 9}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 8.4,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.57,
#  'Mg': 3.6,
#  'Na': 13.0,
#  'RI': 1.51755,
#  'Si': 72.99,
#  'index': 10}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 8.09,
#  'Class': 1,
#  'Fe': 0.24,
#  'K': 0.67,
#  'Mg': 3.46,
#  'Na': 12.72,
#  'RI': 1.5157100000000001,
#  'Si': 73.2,
#  'index': 11}
# {'Al': 1.27,
#  'Ba': 0.0,
#  'Ca': 8.56,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.66,
#  'Na': 12.8,
#  'RI': 1.51763,
#  'Si': 73.01,
#  'index': 12}
# {'Al': 1.4,
#  'Ba': 0.0,
#  'Ca': 8.05,
#  'Class': 1,
#  'Fe': 0.24,
#  'K': 0.69,
#  'Mg': 3.43,
#  'Na': 12.88,
#  'RI': 1.51589,
#  'Si': 73.28,
#  'index': 13}
# {'Al': 1.27,
#  'Ba': 0.0,
#  'Ca': 8.38,
#  'Class': 1,
#  'Fe': 0.17,
#  'K': 0.54,
#  'Mg': 3.56,
#  'Na': 12.86,
#  'RI': 1.51748,
#  'Si': 73.21,
#  'index': 14}
# {'Al': 1.31,
#  'Ba': 0.0,
#  'Ca': 8.5,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.59,
#  'Na': 12.61,
#  'RI': 1.51763,
#  'Si': 73.29,
#  'index': 15}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.39,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.54,
#  'Na': 12.81,
#  'RI': 1.5176100000000001,
#  'Si': 73.24,
#  'index': 16}
# {'Al': 1.16,
#  'Ba': 0.0,
#  'Ca': 8.7,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.67,
#  'Na': 12.68,
#  'RI': 1.5178399999999999,
#  'Si': 73.11,
#  'index': 17}
# {'Al': 0.89,
#  'Ba': 0.0,
#  'Ca': 9.15,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.15,
#  'Mg': 3.85,
#  'Na': 14.36,
#  'RI': 1.52196,
#  'Si': 71.36,
#  'index': 18}
# {'Al': 1.18,
#  'Ba': 0.0,
#  'Ca': 8.89,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 3.73,
#  'Na': 13.9,
#  'RI': 1.51911,
#  'Si': 72.12,
#  'index': 19}
# {'Al': 1.69,
#  'Ba': 0.0,
#  'Ca': 8.44,
#  'Class': 1,
#  'Fe': 0.07,
#  'K': 0.54,
#  'Mg': 3.54,
#  'Na': 13.02,
#  'RI': 1.51735,
#  'Si': 72.73,
#  'index': 20}
# {'Al': 1.49,
#  'Ba': 0.0,
#  'Ca': 8.52,
#  'Class': 1,
#  'Fe': 0.19,
#  'K': 0.54,
#  'Mg': 3.55,
#  'Na': 12.82,
#  'RI': 1.5175,
#  'Si': 72.75,
#  'index': 21}
# {'Al': 0.29,
#  'Ba': 0.0,
#  'Ca': 9.0,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.03,
#  'Mg': 3.75,
#  'Na': 14.77,
#  'RI': 1.51966,
#  'Si': 72.02,
#  'index': 22}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 8.7,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.62,
#  'Na': 12.78,
#  'RI': 1.51736,
#  'Si': 72.79,
#  'index': 23}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 8.59,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.62,
#  'Mg': 3.57,
#  'Na': 12.81,
#  'RI': 1.5175100000000001,
#  'Si': 73.02,
#  'index': 24}
# {'Al': 1.15,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.5,
#  'Mg': 3.5,
#  'Na': 13.38,
#  'RI': 1.5172,
#  'Si': 72.85,
#  'index': 25}
# {'Al': 1.21,
#  'Ba': 0.0,
#  'Ca': 8.53,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.65,
#  'Mg': 3.54,
#  'Na': 12.98,
#  'RI': 1.5176399999999999,
#  'Si': 73.0,
#  'index': 26}
# {'Al': 1.41,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.48,
#  'Na': 13.21,
#  'RI': 1.51793,
#  'Si': 72.64,
#  'index': 27}
# {'Al': 1.33,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.48,
#  'Na': 12.87,
#  'RI': 1.51721,
#  'Si': 73.04,
#  'index': 28}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 8.54,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.52,
#  'Na': 12.56,
#  'RI': 1.51768,
#  'Si': 73.15,
#  'index': 29}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 8.49,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.49,
#  'Na': 13.08,
#  'RI': 1.5178399999999999,
#  'Si': 72.86,
#  'index': 30}
# {'Al': 1.3,
#  'Ba': 0.0,
#  'Ca': 8.69,
#  'Class': 1,
#  'Fe': 0.14,
#  'K': 0.61,
#  'Mg': 3.56,
#  'Na': 12.65,
#  'RI': 1.51768,
#  'Si': 73.08,
#  'index': 31}
# {'Al': 1.14,
#  'Ba': 0.0,
#  'Ca': 8.55,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.5,
#  'Na': 12.84,
#  'RI': 1.51747,
#  'Si': 73.27,
#  'index': 32}
# {'Al': 1.23,
#  'Ba': 0.09,
#  'Ca': 8.56,
#  'Class': 1,
#  'Fe': 0.22,
#  'K': 0.61,
#  'Mg': 3.48,
#  'Na': 12.85,
#  'RI': 1.51775,
#  'Si': 72.97,
#  'index': 33}
# {'Al': 1.38,
#  'Ba': 0.0,
#  'Ca': 8.55,
#  'Class': 1,
#  'Fe': 0.06,
#  'K': 0.6,
#  'Mg': 3.47,
#  'Na': 12.57,
#  'RI': 1.5175299999999998,
#  'Si': 73.39,
#  'index': 34}
# {'Al': 1.34,
#  'Ba': 0.0,
#  'Ca': 8.75,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.54,
#  'Na': 12.69,
#  'RI': 1.51783,
#  'Si': 72.95,
#  'index': 35}
# {'Al': 1.21,
#  'Ba': 0.0,
#  'Ca': 8.57,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.45,
#  'Na': 13.29,
#  'RI': 1.51567,
#  'Si': 72.74,
#  'index': 36}
# {'Al': 1.32,
#  'Ba': 0.11,
#  'Ca': 8.78,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.51,
#  'Mg': 3.53,
#  'Na': 13.89,
#  'RI': 1.51909,
#  'Si': 71.81,
#  'index': 37}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 8.68,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.48,
#  'Na': 12.74,
#  'RI': 1.51797,
#  'Si': 72.96,
#  'index': 38}
# {'Al': 0.47,
#  'Ba': 0.0,
#  'Ca': 9.57,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.82,
#  'Na': 14.21,
#  'RI': 1.52213,
#  'Si': 71.77,
#  'index': 39}
# {'Al': 0.47,
#  'Ba': 0.0,
#  'Ca': 9.57,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.82,
#  'Na': 14.21,
#  'RI': 1.52213,
#  'Si': 71.77,
#  'index': 40}
# {'Al': 1.12,
#  'Ba': 0.0,
#  'Ca': 8.77,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.5,
#  'Na': 12.79,
#  'RI': 1.51793,
#  'Si': 73.03,
#  'index': 41}
# {'Al': 1.2,
#  'Ba': 0.0,
#  'Ca': 8.64,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.42,
#  'Na': 12.71,
#  'RI': 1.51755,
#  'Si': 73.2,
#  'index': 42}
# {'Al': 1.33,
#  'Ba': 0.0,
#  'Ca': 8.59,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.39,
#  'Na': 13.21,
#  'RI': 1.51779,
#  'Si': 72.76,
#  'index': 43}
# {'Al': 0.72,
#  'Ba': 0.0,
#  'Ca': 9.74,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.17,
#  'Mg': 3.84,
#  'Na': 13.73,
#  'RI': 1.5221,
#  'Si': 71.76,
#  'index': 44}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.76,
#  'Class': 1,
#  'Fe': 0.3,
#  'K': 0.62,
#  'Mg': 3.43,
#  'Na': 12.73,
#  'RI': 1.51786,
#  'Si': 72.95,
#  'index': 45}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 9.0,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 3.48,
#  'Na': 13.49,
#  'RI': 1.519,
#  'Si': 71.95,
#  'index': 46}
# {'Al': 1.18,
#  'Ba': 0.0,
#  'Ca': 8.83,
#  'Class': 1,
#  'Fe': 0.16,
#  'K': 0.57,
#  'Mg': 3.37,
#  'Na': 13.19,
#  'RI': 1.5186899999999999,
#  'Si': 72.72,
#  'index': 47}
# {'Al': 0.71,
#  'Ba': 0.0,
#  'Ca': 9.82,
#  'Class': 1,
#  'Fe': 0.1,
#  'K': 0.02,
#  'Mg': 3.7,
#  'Na': 13.99,
#  'RI': 1.52667,
#  'Si': 71.57,
#  'index': 48}
# {'Al': 0.79,
#  'Ba': 0.0,
#  'Ca': 10.02,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.13,
#  'Mg': 3.77,
#  'Na': 13.21,
#  'RI': 1.52223,
#  'Si': 71.99,
#  'index': 49}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.91,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.35,
#  'Na': 13.58,
#  'RI': 1.51898,
#  'Si': 72.08,
#  'index': 50}
# {'Al': 0.51,
#  'Ba': 0.0,
#  'Ca': 10.06,
#  'Class': 1,
#  'Fe': 0.16,
#  'K': 0.09,
#  'Mg': 3.72,
#  'Na': 13.72,
#  'RI': 1.5232,
#  'Si': 71.75,
#  'index': 51}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 9.14,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.6,
#  'Mg': 3.33,
#  'Na': 13.2,
#  'RI': 1.51926,
#  'Si': 72.36,
#  'index': 52}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 9.03,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 2.87,
#  'Na': 13.43,
#  'RI': 1.5180799999999999,
#  'Si': 72.84,
#  'index': 53}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 9.07,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 2.84,
#  'Na': 13.14,
#  'RI': 1.51837,
#  'Si': 72.85,
#  'index': 54}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 9.02,
#  'Class': 1,
#  'Fe': 0.09,
#  'K': 0.51,
#  'Mg': 2.81,
#  'Na': 13.21,
#  'RI': 1.51778,
#  'Si': 72.98,
#  'index': 55}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 9.06,
#  'Class': 1,
#  'Fe': 0.24,
#  'K': 0.56,
#  'Mg': 2.71,
#  'Na': 12.45,
#  'RI': 1.51769,
#  'Si': 73.7,
#  'index': 56}
# {'Al': 1.12,
#  'Ba': 0.0,
#  'Ca': 8.35,
#  'Class': 1,
#  'Fe': 0.31,
#  'K': 0.62,
#  'Mg': 3.47,
#  'Na': 12.99,
#  'RI': 1.51215,
#  'Si': 72.98,
#  'index': 57}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.48,
#  'Na': 12.87,
#  'RI': 1.51824,
#  'Si': 72.95,
#  'index': 58}
# {'Al': 1.17,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.74,
#  'Na': 13.48,
#  'RI': 1.51754,
#  'Si': 72.99,
#  'index': 59}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.27,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.57,
#  'Mg': 3.66,
#  'Na': 13.39,
#  'RI': 1.51754,
#  'Si': 72.79,
#  'index': 60}
# {'Al': 1.11,
#  'Ba': 0.0,
#  'Ca': 8.76,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.14,
#  'Mg': 3.62,
#  'Na': 13.6,
#  'RI': 1.51905,
#  'Si': 72.64,
#  'index': 61}
# {'Al': 1.32,
#  'Ba': 0.69,
#  'Ca': 8.67,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.12,
#  'Mg': 3.58,
#  'Na': 13.81,
#  'RI': 1.51977,
#  'Si': 71.72,
#  'index': 62}
# {'Al': 0.88,
#  'Ba': 0.0,
#  'Ca': 9.54,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.23,
#  'Mg': 3.86,
#  'Na': 13.51,
#  'RI': 1.5217200000000002,
#  'Si': 71.79,
#  'index': 63}
# {'Al': 0.78,
#  'Ba': 0.0,
#  'Ca': 9.69,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 3.81,
#  'Na': 14.17,
#  'RI': 1.52227,
#  'Si': 71.35,
#  'index': 64}
# {'Al': 0.9,
#  'Ba': 0.0,
#  'Ca': 9.61,
#  'Class': 1,
#  'Fe': 0.07,
#  'K': 0.18,
#  'Mg': 3.74,
#  'Na': 13.48,
#  'RI': 1.5217200000000002,
#  'Si': 72.01,
#  'index': 65}
# {'Al': 1.12,
#  'Ba': 0.0,
#  'Ca': 9.4,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.09,
#  'Mg': 3.59,
#  'Na': 13.69,
#  'RI': 1.52099,
#  'Si': 71.96,
#  'index': 66}
# {'Al': 0.87,
#  'Ba': 0.0,
#  'Ca': 9.85,
#  'Class': 1,
#  'Fe': 0.17,
#  'K': 0.19,
#  'Mg': 3.65,
#  'Na': 13.05,
#  'RI': 1.52152,
#  'Si': 72.22,
#  'index': 67}
# {'Al': 0.87,
#  'Ba': 0.0,
#  'Ca': 9.85,
#  'Class': 1,
#  'Fe': 0.17,
#  'K': 0.19,
#  'Mg': 3.65,
#  'Na': 13.05,
#  'RI': 1.52152,
#  'Si': 72.32,
#  'index': 68}
# {'Al': 0.9,
#  'Ba': 0.0,
#  'Ca': 9.82,
#  'Class': 1,
#  'Fe': 0.16,
#  'K': 0.23,
#  'Mg': 3.58,
#  'Na': 13.12,
#  'RI': 1.52152,
#  'Si': 72.2,
#  'index': 69}
# {'Al': 0.82,
#  'Ba': 0.0,
#  'Ca': 10.17,
#  'Class': 1,
#  'Fe': 0.03,
#  'K': 0.12,
#  'Mg': 3.58,
#  'Na': 13.31,
#  'RI': 1.523,
#  'Si': 71.99,
#  'index': 70}
# {'Al': 1.74,
#  'Ba': 0.0,
#  'Ca': 7.36,
#  'Class': 2,
#  'Fe': 0.12,
#  'K': 0.16,
#  'Mg': 3.67,
#  'Na': 14.86,
#  'RI': 1.5157399999999999,
#  'Si': 71.87,
#  'index': 71}
# {'Al': 1.27,
#  'Ba': 0.0,
#  'Ca': 8.32,
#  'Class': 2,
#  'Fe': 0.32,
#  'K': 0.54,
#  'Mg': 3.87,
#  'Na': 13.64,
#  'RI': 1.5184799999999998,
#  'Si': 71.96,
#  'index': 72}
# {'Al': 1.52,
#  'Ba': 0.0,
#  'Ca': 7.83,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.67,
#  'Mg': 3.59,
#  'Na': 13.09,
#  'RI': 1.51593,
#  'Si': 73.1,
#  'index': 73}
# {'Al': 1.57,
#  'Ba': 0.0,
#  'Ca': 7.89,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.57,
#  'Na': 13.34,
#  'RI': 1.51631,
#  'Si': 72.87,
#  'index': 74}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.9,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.72,
#  'Mg': 3.56,
#  'Na': 13.02,
#  'RI': 1.51596,
#  'Si': 73.11,
#  'index': 75}
# {'Al': 1.51,
#  'Ba': 0.0,
#  'Ca': 7.96,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.69,
#  'Mg': 3.58,
#  'Na': 13.02,
#  'RI': 1.5159,
#  'Si': 73.12,
#  'index': 76}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.66,
#  'Mg': 3.61,
#  'Na': 13.44,
#  'RI': 1.51645,
#  'Si': 72.39,
#  'index': 77}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.04,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.58,
#  'Na': 13.0,
#  'RI': 1.51627,
#  'Si': 72.83,
#  'index': 78}
# {'Al': 1.25,
#  'Ba': 0.0,
#  'Ca': 7.94,
#  'Class': 2,
#  'Fe': 0.14,
#  'K': 0.37,
#  'Mg': 3.52,
#  'Na': 13.92,
#  'RI': 1.51613,
#  'Si': 72.88,
#  'index': 79}
# {'Al': 1.9,
#  'Ba': 0.0,
#  'Ca': 7.97,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.69,
#  'Mg': 3.52,
#  'Na': 12.82,
#  'RI': 1.5159,
#  'Si': 72.86,
#  'index': 80}
# {'Al': 2.12,
#  'Ba': 0.0,
#  'Ca': 7.97,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.69,
#  'Mg': 3.52,
#  'Na': 12.86,
#  'RI': 1.5159200000000002,
#  'Si': 72.66,
#  'index': 81}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 7.86,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.45,
#  'Na': 13.25,
#  'RI': 1.51593,
#  'Si': 73.17,
#  'index': 82}
# {'Al': 1.25,
#  'Ba': 0.0,
#  'Ca': 8.1,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.68,
#  'Mg': 3.55,
#  'Na': 13.41,
#  'RI': 1.5164600000000001,
#  'Si': 72.81,
#  'index': 83}
# {'Al': 1.55,
#  'Ba': 0.0,
#  'Ca': 8.05,
#  'Class': 2,
#  'Fe': 0.09,
#  'K': 0.68,
#  'Mg': 3.52,
#  'Na': 13.09,
#  'RI': 1.51594,
#  'Si': 72.87,
#  'index': 84}
# {'Al': 2.08,
#  'Ba': 0.0,
#  'Ca': 7.08,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 1.1,
#  'Mg': 3.09,
#  'Na': 14.25,
#  'RI': 1.51409,
#  'Si': 72.28,
#  'index': 85}
# {'Al': 1.49,
#  'Ba': 0.0,
#  'Ca': 8.21,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.45,
#  'Mg': 3.58,
#  'Na': 13.36,
#  'RI': 1.51625,
#  'Si': 72.72,
#  'index': 86}
# {'Al': 1.47,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.38,
#  'Mg': 3.49,
#  'Na': 13.24,
#  'RI': 1.51569,
#  'Si': 73.25,
#  'index': 87}
# {'Al': 1.52,
#  'Ba': 0.0,
#  'Ca': 8.08,
#  'Class': 2,
#  'Fe': 0.1,
#  'K': 0.67,
#  'Mg': 3.49,
#  'Na': 13.4,
#  'RI': 1.51645,
#  'Si': 72.65,
#  'index': 88}
# {'Al': 1.48,
#  'Ba': 0.0,
#  'Ca': 8.12,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.5,
#  'Na': 13.01,
#  'RI': 1.5161799999999999,
#  'Si': 72.89,
#  'index': 89}
# {'Al': 1.87,
#  'Ba': 0.0,
#  'Ca': 8.08,
#  'Class': 2,
#  'Fe': 0.09,
#  'K': 0.63,
#  'Mg': 3.48,
#  'Na': 12.55,
#  'RI': 1.5164,
#  'Si': 73.23,
#  'index': 90}
# {'Al': 1.11,
#  'Ba': 0.0,
#  'Ca': 8.96,
#  'Class': 2,
#  'Fe': 0.22,
#  'K': 0.64,
#  'Mg': 3.74,
#  'Na': 12.93,
#  'RI': 1.51841,
#  'Si': 72.28,
#  'index': 91}
# {'Al': 1.45,
#  'Ba': 0.0,
#  'Ca': 8.27,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.44,
#  'Mg': 3.44,
#  'Na': 12.9,
#  'RI': 1.51605,
#  'Si': 73.06,
#  'index': 92}
# {'Al': 1.58,
#  'Ba': 0.0,
#  'Ca': 8.39,
#  'Class': 2,
#  'Fe': 0.19,
#  'K': 0.07,
#  'Mg': 3.41,
#  'Na': 13.12,
#  'RI': 1.51588,
#  'Si': 73.26,
#  'index': 93}
# {'Al': 1.47,
#  'Ba': 0.0,
#  'Ca': 8.22,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.39,
#  'Mg': 3.34,
#  'Na': 13.24,
#  'RI': 1.5159,
#  'Si': 73.1,
#  'index': 94}
# {'Al': 1.49,
#  'Ba': 0.0,
#  'Ca': 8.24,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.67,
#  'Mg': 3.33,
#  'Na': 12.71,
#  'RI': 1.51629,
#  'Si': 73.28,
#  'index': 95}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 8.6,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.51,
#  'Mg': 3.43,
#  'Na': 13.36,
#  'RI': 1.5186,
#  'Si': 72.26,
#  'index': 96}
# {'Al': 1.06,
#  'Ba': 0.0,
#  'Ca': 9.13,
#  'Class': 2,
#  'Fe': 0.15,
#  'K': 0.64,
#  'Mg': 3.62,
#  'Na': 13.02,
#  'RI': 1.51841,
#  'Si': 72.34,
#  'index': 97}
# {'Al': 1.16,
#  'Ba': 0.0,
#  'Ca': 8.9,
#  'Class': 2,
#  'Fe': 0.24,
#  'K': 0.62,
#  'Mg': 3.25,
#  'Na': 12.2,
#  'RI': 1.5174299999999998,
#  'Si': 73.55,
#  'index': 98}
# {'Al': 1.71,
#  'Ba': 0.0,
#  'Ca': 8.54,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.73,
#  'Mg': 2.88,
#  'Na': 12.67,
#  'RI': 1.51689,
#  'Si': 73.21,
#  'index': 99}
# {'Al': 1.43,
#  'Ba': 0.14,
#  'Ca': 8.79,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 2.96,
#  'Na': 12.96,
#  'RI': 1.51811,
#  'Si': 72.92,
#  'index': 100}
# {'Al': 1.44,
#  'Ba': 0.11,
#  'Ca': 8.79,
#  'Class': 2,
#  'Fe': 0.22,
#  'K': 0.57,
#  'Mg': 2.85,
#  'Na': 12.75,
#  'RI': 1.51655,
#  'Si': 73.27,
#  'index': 101}
# {'Al': 1.63,
#  'Ba': 0.0,
#  'Ca': 9.23,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.7,
#  'Mg': 2.72,
#  'Na': 12.35,
#  'RI': 1.5173,
#  'Si': 72.87,
#  'index': 102}
# {'Al': 0.83,
#  'Ba': 0.0,
#  'Ca': 9.42,
#  'Class': 2,
#  'Fe': 0.2,
#  'K': 0.35,
#  'Mg': 2.76,
#  'Na': 12.62,
#  'RI': 1.5182,
#  'Si': 73.81,
#  'index': 103}
# {'Al': 0.66,
#  'Ba': 0.0,
#  'Ca': 11.64,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.08,
#  'Mg': 3.15,
#  'Na': 13.8,
#  'RI': 1.52725,
#  'Si': 70.57,
#  'index': 104}
# {'Al': 1.17,
#  'Ba': 0.0,
#  'Ca': 10.79,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.08,
#  'Mg': 2.9,
#  'Na': 13.83,
#  'RI': 1.5241,
#  'Si': 71.15,
#  'index': 105}
# {'Al': 1.88,
#  'Ba': 0.0,
#  'Ca': 13.24,
#  'Class': 2,
#  'Fe': 0.34,
#  'K': 0.81,
#  'Mg': 0.0,
#  'Na': 11.45,
#  'RI': 1.52475,
#  'Si': 72.19,
#  'index': 106}
# {'Al': 2.1,
#  'Ba': 3.15,
#  'Ca': 13.3,
#  'Class': 2,
#  'Fe': 0.28,
#  'K': 0.58,
#  'Mg': 0.0,
#  'Na': 10.73,
#  'RI': 1.53125,
#  'Si': 69.81,
#  'index': 107}
# {'Al': 1.0,
#  'Ba': 0.0,
#  'Ca': 16.19,
#  'Class': 2,
#  'Fe': 0.24,
#  'K': 0.12,
#  'Mg': 0.0,
#  'Na': 12.3,
#  'RI': 1.53393,
#  'Si': 70.16,
#  'index': 108}
# {'Al': 1.0,
#  'Ba': 0.0,
#  'Ca': 11.52,
#  'Class': 2,
#  'Fe': 0.08,
#  'K': 0.1,
#  'Mg': 0.0,
#  'Na': 14.43,
#  'RI': 1.5222200000000001,
#  'Si': 72.67,
#  'index': 109}
# {'Al': 0.56,
#  'Ba': 0.0,
#  'Ca': 10.99,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 13.72,
#  'RI': 1.5181799999999999,
#  'Si': 74.45,
#  'index': 110}
# {'Al': 0.77,
#  'Ba': 0.0,
#  'Ca': 14.68,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 11.23,
#  'RI': 1.52664,
#  'Si': 73.21,
#  'index': 111}
# {'Al': 0.75,
#  'Ba': 0.0,
#  'Ca': 14.96,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 11.02,
#  'RI': 1.52739,
#  'Si': 73.08,
#  'index': 112}
# {'Al': 0.67,
#  'Ba': 0.0,
#  'Ca': 14.4,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 0.0,
#  'Na': 12.64,
#  'RI': 1.52777,
#  'Si': 72.02,
#  'index': 113}
# {'Al': 1.26,
#  'Ba': 0.0,
#  'Ca': 8.21,
#  'Class': 2,
#  'Fe': 0.14,
#  'K': 0.57,
#  'Mg': 3.83,
#  'Na': 13.46,
#  'RI': 1.51892,
#  'Si': 72.55,
#  'index': 114}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.97,
#  'Na': 13.1,
#  'RI': 1.51847,
#  'Si': 72.44,
#  'index': 115}
# {'Al': 1.33,
#  'Ba': 0.0,
#  'Ca': 8.28,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.51,
#  'Mg': 3.89,
#  'Na': 13.41,
#  'RI': 1.5184600000000001,
#  'Si': 72.38,
#  'index': 116}
# {'Al': 1.41,
#  'Ba': 0.0,
#  'Ca': 8.31,
#  'Class': 2,
#  'Fe': 0.1,
#  'K': 0.55,
#  'Mg': 3.9,
#  'Na': 13.24,
#  'RI': 1.51829,
#  'Si': 72.33,
#  'index': 117}
# {'Al': 1.81,
#  'Ba': 0.0,
#  'Ca': 7.88,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.68,
#  'Na': 13.72,
#  'RI': 1.51708,
#  'Si': 72.06,
#  'index': 118}
# {'Al': 1.53,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.29,
#  'K': 0.65,
#  'Mg': 3.64,
#  'Na': 13.3,
#  'RI': 1.51673,
#  'Si': 72.53,
#  'index': 119}
# {'Al': 1.47,
#  'Ba': 0.0,
#  'Ca': 7.96,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.57,
#  'Na': 13.56,
#  'RI': 1.51652,
#  'Si': 72.45,
#  'index': 120}
# {'Al': 1.32,
#  'Ba': 0.0,
#  'Ca': 8.42,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.76,
#  'Na': 13.25,
#  'RI': 1.51844,
#  'Si': 72.4,
#  'index': 121}
# {'Al': 1.62,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.21,
#  'K': 0.64,
#  'Mg': 3.54,
#  'Na': 12.93,
#  'RI': 1.51663,
#  'Si': 72.96,
#  'index': 122}
# {'Al': 1.48,
#  'Ba': 0.0,
#  'Ca': 8.1,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.54,
#  'Na': 13.23,
#  'RI': 1.5168700000000002,
#  'Si': 72.84,
#  'index': 123}
# {'Al': 1.71,
#  'Ba': 0.0,
#  'Ca': 7.99,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.62,
#  'Mg': 3.48,
#  'Na': 13.48,
#  'RI': 1.5170700000000001,
#  'Si': 72.52,
#  'index': 124}
# {'Al': 1.15,
#  'Ba': 0.0,
#  'Ca': 8.52,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.54,
#  'Mg': 3.68,
#  'Na': 13.2,
#  'RI': 1.52177,
#  'Si': 72.75,
#  'index': 125}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 8.55,
#  'Class': 2,
#  'Fe': 0.12,
#  'K': 0.58,
#  'Mg': 3.66,
#  'Na': 12.93,
#  'RI': 1.51872,
#  'Si': 72.51,
#  'index': 126}
# {'Al': 1.26,
#  'Ba': 0.0,
#  'Ca': 8.6,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.61,
#  'Na': 12.94,
#  'RI': 1.51667,
#  'Si': 72.75,
#  'index': 127}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 9.85,
#  'Class': 2,
#  'Fe': 0.17,
#  'K': 0.49,
#  'Mg': 2.28,
#  'Na': 13.78,
#  'RI': 1.52081,
#  'Si': 71.99,
#  'index': 128}
# {'Al': 1.67,
#  'Ba': 0.27,
#  'Ca': 9.57,
#  'Class': 2,
#  'Fe': 0.17,
#  'K': 0.53,
#  'Mg': 2.09,
#  'Na': 13.55,
#  'RI': 1.52068,
#  'Si': 72.18,
#  'index': 129}
# {'Al': 1.63,
#  'Ba': 0.0,
#  'Ca': 10.56,
#  'Class': 2,
#  'Fe': 0.18,
#  'K': 0.39,
#  'Mg': 1.35,
#  'Na': 13.98,
#  'RI': 1.5202,
#  'Si': 71.76,
#  'index': 130}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 11.14,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.33,
#  'Mg': 1.01,
#  'Na': 13.75,
#  'RI': 1.52177,
#  'Si': 72.19,
#  'index': 131}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 13.44,
#  'Class': 2,
#  'Fe': 0.1,
#  'K': 0.19,
#  'Mg': 0.0,
#  'Na': 13.7,
#  'RI': 1.52614,
#  'Si': 71.24,
#  'index': 132}
# {'Al': 1.18,
#  'Ba': 0.0,
#  'Ca': 8.15,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.98,
#  'Na': 13.43,
#  'RI': 1.51813,
#  'Si': 72.49,
#  'index': 133}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.21,
#  'Class': 2,
#  'Fe': 0.15,
#  'K': 0.54,
#  'Mg': 3.93,
#  'Na': 13.71,
#  'RI': 1.518,
#  'Si': 71.81,
#  'index': 134}
# {'Al': 1.25,
#  'Ba': 0.0,
#  'Ca': 8.12,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.52,
#  'Mg': 3.85,
#  'Na': 13.33,
#  'RI': 1.51811,
#  'Si': 72.78,
#  'index': 135}
# {'Al': 1.3,
#  'Ba': 0.0,
#  'Ca': 8.44,
#  'Class': 2,
#  'Fe': 0.28,
#  'K': 0.55,
#  'Mg': 3.9,
#  'Na': 13.19,
#  'RI': 1.51789,
#  'Si': 72.33,
#  'index': 136}
# {'Al': 1.08,
#  'Ba': 0.0,
#  'Ca': 8.38,
#  'Class': 2,
#  'Fe': 0.12,
#  'K': 0.56,
#  'Mg': 3.8,
#  'Na': 13.0,
#  'RI': 1.51806,
#  'Si': 73.07,
#  'index': 137}
# {'Al': 1.57,
#  'Ba': 0.0,
#  'Ca': 8.11,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.62,
#  'Na': 12.89,
#  'RI': 1.51711,
#  'Si': 72.96,
#  'index': 138}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.9,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.66,
#  'Mg': 3.52,
#  'Na': 12.79,
#  'RI': 1.51674,
#  'Si': 73.36,
#  'index': 139}
# {'Al': 1.64,
#  'Ba': 0.0,
#  'Ca': 7.99,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.65,
#  'Mg': 3.56,
#  'Na': 12.87,
#  'RI': 1.51674,
#  'Si': 73.14,
#  'index': 140}
# {'Al': 1.61,
#  'Ba': 0.0,
#  'Ca': 8.11,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.68,
#  'Mg': 3.54,
#  'Na': 13.33,
#  'RI': 1.5169,
#  'Si': 72.54,
#  'index': 141}
# {'Al': 1.07,
#  'Ba': 0.09,
#  'Ca': 8.41,
#  'Class': 2,
#  'Fe': 0.17,
#  'K': 0.57,
#  'Mg': 3.63,
#  'Na': 13.2,
#  'RI': 1.51851,
#  'Si': 72.83,
#  'index': 142}
# {'Al': 1.44,
#  'Ba': 0.06,
#  'Ca': 8.23,
#  'Class': 2,
#  'Fe': 0.25,
#  'K': 0.68,
#  'Mg': 3.51,
#  'Na': 12.85,
#  'RI': 1.51662,
#  'Si': 73.01,
#  'index': 143}
# {'Al': 1.79,
#  'Ba': 0.0,
#  'Ca': 8.18,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.66,
#  'Mg': 3.47,
#  'Na': 13.0,
#  'RI': 1.51709,
#  'Si': 72.72,
#  'index': 144}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.81,
#  'Class': 2,
#  'Fe': 0.24,
#  'K': 0.58,
#  'Mg': 3.18,
#  'Na': 12.99,
#  'RI': 1.5166,
#  'Si': 72.97,
#  'index': 145}
# {'Al': 1.24,
#  'Ba': 0.0,
#  'Ca': 8.68,
#  'Class': 2,
#  'Fe': 0.35,
#  'K': 0.62,
#  'Mg': 3.67,
#  'Na': 12.85,
#  'RI': 1.51839,
#  'Si': 72.57,
#  'index': 146}
# {'Al': 1.11,
#  'Ba': 0.0,
#  'Ca': 8.6,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.66,
#  'Na': 13.65,
#  'RI': 1.51769,
#  'Si': 72.77,
#  'index': 147}
# {'Al': 1.34,
#  'Ba': 0.0,
#  'Ca': 8.33,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.53,
#  'Na': 13.33,
#  'RI': 1.5161,
#  'Si': 72.67,
#  'index': 148}
# {'Al': 1.38,
#  'Ba': 0.0,
#  'Ca': 8.44,
#  'Class': 3,
#  'Fe': 0.1,
#  'K': 0.56,
#  'Mg': 3.57,
#  'Na': 13.24,
#  'RI': 1.5167,
#  'Si': 72.7,
#  'index': 149}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 8.53,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.52,
#  'Na': 12.16,
#  'RI': 1.51643,
#  'Si': 72.89,
#  'index': 150}
# {'Al': 1.76,
#  'Ba': 0.0,
#  'Ca': 8.38,
#  'Class': 3,
#  'Fe': 0.17,
#  'K': 0.6,
#  'Mg': 3.45,
#  'Na': 13.14,
#  'RI': 1.51665,
#  'Si': 72.48,
#  'index': 151}
# {'Al': 0.83,
#  'Ba': 0.0,
#  'Ca': 9.49,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 3.9,
#  'Na': 14.32,
#  'RI': 1.5212700000000001,
#  'Si': 71.5,
#  'index': 152}
# {'Al': 0.65,
#  'Ba': 0.0,
#  'Ca': 8.93,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 3.65,
#  'Na': 13.64,
#  'RI': 1.51779,
#  'Si': 73.0,
#  'index': 153}
# {'Al': 1.22,
#  'Ba': 0.0,
#  'Ca': 8.32,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.4,
#  'Na': 13.42,
#  'RI': 1.5161,
#  'Si': 72.69,
#  'index': 154}
# {'Al': 1.31,
#  'Ba': 0.0,
#  'Ca': 8.79,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.58,
#  'Na': 12.86,
#  'RI': 1.51694,
#  'Si': 72.61,
#  'index': 155}
# {'Al': 1.26,
#  'Ba': 0.0,
#  'Ca': 8.58,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.52,
#  'Mg': 3.4,
#  'Na': 13.04,
#  'RI': 1.5164600000000001,
#  'Si': 73.01,
#  'index': 156}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 8.65,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.52,
#  'Mg': 3.39,
#  'Na': 13.41,
#  'RI': 1.51655,
#  'Si': 72.64,
#  'index': 157}
# {'Al': 0.58,
#  'Ba': 0.0,
#  'Ca': 9.65,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.76,
#  'Na': 14.03,
#  'RI': 1.52121,
#  'Si': 71.79,
#  'index': 158}
# {'Al': 1.52,
#  'Ba': 0.0,
#  'Ca': 8.79,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.41,
#  'Na': 13.53,
#  'RI': 1.51776,
#  'Si': 72.04,
#  'index': 159}
# {'Al': 1.63,
#  'Ba': 0.0,
#  'Ca': 8.81,
#  'Class': 3,
#  'Fe': 0.09,
#  'K': 0.57,
#  'Mg': 3.36,
#  'Na': 13.5,
#  'RI': 1.51796,
#  'Si': 71.94,
#  'index': 160}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.99,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.34,
#  'Na': 13.33,
#  'RI': 1.5183200000000001,
#  'Si': 72.14,
#  'index': 161}
# {'Al': 0.75,
#  'Ba': 0.15,
#  'Ca': 8.89,
#  'Class': 3,
#  'Fe': 0.24,
#  'K': 0.16,
#  'Mg': 3.54,
#  'Na': 13.64,
#  'RI': 1.51934,
#  'Si': 72.65,
#  'index': 162}
# {'Al': 0.91,
#  'Ba': 0.0,
#  'Ca': 9.14,
#  'Class': 3,
#  'Fe': 0.37,
#  'K': 0.23,
#  'Mg': 3.78,
#  'Na': 14.19,
#  'RI': 1.52211,
#  'Si': 71.36,
#  'index': 163}
# {'Al': 3.5,
#  'Ba': 2.2,
#  'Ca': 5.87,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 1.68,
#  'Mg': 2.68,
#  'Na': 14.01,
#  'RI': 1.51514,
#  'Si': 69.89,
#  'index': 164}
# {'Al': 1.86,
#  'Ba': 0.0,
#  'Ca': 10.09,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 1.85,
#  'Na': 12.73,
#  'RI': 1.51915,
#  'Si': 72.69,
#  'index': 165}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 11.41,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.47,
#  'Mg': 1.88,
#  'Na': 11.56,
#  'RI': 1.5217100000000001,
#  'Si': 72.86,
#  'index': 166}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 11.62,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 1.71,
#  'Na': 11.03,
#  'RI': 1.5215100000000001,
#  'Si': 73.44,
#  'index': 167}
# {'Al': 1.65,
#  'Ba': 0.0,
#  'Ca': 11.53,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.38,
#  'Mg': 0.0,
#  'Na': 12.64,
#  'RI': 1.51969,
#  'Si': 73.75,
#  'index': 168}
# {'Al': 1.83,
#  'Ba': 0.0,
#  'Ca': 10.17,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.97,
#  'Mg': 0.0,
#  'Na': 12.86,
#  'RI': 1.5166600000000001,
#  'Si': 73.88,
#  'index': 169}
# {'Al': 1.76,
#  'Ba': 0.0,
#  'Ca': 11.32,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.47,
#  'Mg': 0.0,
#  'Na': 13.27,
#  'RI': 1.51994,
#  'Si': 73.03,
#  'index': 170}
# {'Al': 1.58,
#  'Ba': 0.0,
#  'Ca': 12.24,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.32,
#  'Mg': 0.0,
#  'Na': 13.44,
#  'RI': 1.52369,
#  'Si': 72.22,
#  'index': 171}
# {'Al': 3.04,
#  'Ba': 0.0,
#  'Ca': 6.96,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 6.21,
#  'Mg': 0.0,
#  'Na': 13.02,
#  'RI': 1.51316,
#  'Si': 70.48,
#  'index': 172}
# {'Al': 3.02,
#  'Ba': 0.0,
#  'Ca': 6.93,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 6.21,
#  'Mg': 0.0,
#  'Na': 13.0,
#  'RI': 1.51321,
#  'Si': 70.7,
#  'index': 173}
# {'Al': 1.4,
#  'Ba': 0.0,
#  'Ca': 12.5,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.33,
#  'Mg': 0.0,
#  'Na': 13.38,
#  'RI': 1.52043,
#  'Si': 72.25,
#  'index': 174}
# {'Al': 2.17,
#  'Ba': 0.24,
#  'Ca': 9.7,
#  'Class': 5,
#  'Fe': 0.51,
#  'K': 0.76,
#  'Mg': 1.61,
#  'Na': 12.85,
#  'RI': 1.5205799999999998,
#  'Si': 72.18,
#  'index': 175}
# {'Al': 1.51,
#  'Ba': 0.0,
#  'Ca': 11.27,
#  'Class': 5,
#  'Fe': 0.28,
#  'K': 0.13,
#  'Mg': 0.33,
#  'Na': 12.97,
#  'RI': 1.52119,
#  'Si': 73.39,
#  'index': 176}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 9.57,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.39,
#  'Na': 14.0,
#  'RI': 1.51905,
#  'Si': 72.37,
#  'index': 177}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 9.77,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.41,
#  'Na': 13.79,
#  'RI': 1.51937,
#  'Si': 72.76,
#  'index': 178}
# {'Al': 1.62,
#  'Ba': 0.0,
#  'Ca': 9.26,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.24,
#  'Na': 14.46,
#  'RI': 1.51829,
#  'Si': 72.38,
#  'index': 179}
# {'Al': 1.66,
#  'Ba': 0.0,
#  'Ca': 9.32,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.19,
#  'Na': 14.09,
#  'RI': 1.51852,
#  'Si': 72.67,
#  'index': 180}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.59,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 1.74,
#  'Na': 14.4,
#  'RI': 1.51299,
#  'Si': 74.55,
#  'index': 181}
# {'Al': 1.74,
#  'Ba': 0.0,
#  'Ca': 9.95,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.78,
#  'Na': 14.99,
#  'RI': 1.51888,
#  'Si': 72.5,
#  'index': 182}
# {'Al': 2.09,
#  'Ba': 0.0,
#  'Ca': 10.88,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.15,
#  'RI': 1.51916,
#  'Si': 72.74,
#  'index': 183}
# {'Al': 0.56,
#  'Ba': 0.0,
#  'Ca': 11.22,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.56,
#  'RI': 1.51969,
#  'Si': 73.48,
#  'index': 184}
# {'Al': 0.34,
#  'Ba': 0.0,
#  'Ca': 6.65,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 17.38,
#  'RI': 1.51115,
#  'Si': 75.41,
#  'index': 185}
# {'Al': 1.81,
#  'Ba': 1.19,
#  'Ca': 5.43,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 1.76,
#  'Mg': 3.2,
#  'Na': 13.69,
#  'RI': 1.51131,
#  'Si': 72.81,
#  'index': 186}
# {'Al': 2.22,
#  'Ba': 1.63,
#  'Ca': 5.79,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 1.46,
#  'Mg': 3.26,
#  'Na': 14.32,
#  'RI': 1.5183799999999998,
#  'Si': 71.25,
#  'index': 187}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.83,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.34,
#  'Na': 13.44,
#  'RI': 1.52315,
#  'Si': 72.38,
#  'index': 188}
# {'Al': 2.06,
#  'Ba': 0.0,
#  'Ca': 9.76,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.76,
#  'Mg': 2.2,
#  'Na': 14.86,
#  'RI': 1.52247,
#  'Si': 70.26,
#  'index': 189}
# {'Al': 1.31,
#  'Ba': 1.68,
#  'Ca': 8.61,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.31,
#  'Mg': 1.83,
#  'Na': 15.79,
#  'RI': 1.52365,
#  'Si': 70.43,
#  'index': 190}
# {'Al': 1.79,
#  'Ba': 0.76,
#  'Ca': 8.67,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 1.78,
#  'Na': 13.88,
#  'RI': 1.51613,
#  'Si': 73.1,
#  'index': 191}
# {'Al': 2.38,
#  'Ba': 0.64,
#  'Ca': 8.76,
#  'Class': 7,
#  'Fe': 0.09,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.85,
#  'RI': 1.5160200000000001,
#  'Si': 73.28,
#  'index': 192}
# {'Al': 2.79,
#  'Ba': 0.4,
#  'Ca': 9.04,
#  'Class': 7,
#  'Fe': 0.09,
#  'K': 0.04,
#  'Mg': 0.0,
#  'Na': 14.2,
#  'RI': 1.51623,
#  'Si': 73.46,
#  'index': 193}
# {'Al': 2.0,
#  'Ba': 1.59,
#  'Ca': 8.53,
#  'Class': 7,
#  'Fe': 0.08,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.75,
#  'RI': 1.51719,
#  'Si': 73.02,
#  'index': 194}
# {'Al': 1.98,
#  'Ba': 1.57,
#  'Ca': 8.52,
#  'Class': 7,
#  'Fe': 0.07,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.56,
#  'RI': 1.51683,
#  'Si': 73.29,
#  'index': 195}
# {'Al': 2.68,
#  'Ba': 0.61,
#  'Ca': 9.07,
#  'Class': 7,
#  'Fe': 0.05,
#  'K': 0.08,
#  'Mg': 0.0,
#  'Na': 14.14,
#  'RI': 1.51545,
#  'Si': 73.39,
#  'index': 196}
# {'Al': 2.54,
#  'Ba': 0.81,
#  'Ca': 9.41,
#  'Class': 7,
#  'Fe': 0.01,
#  'K': 0.14,
#  'Mg': 0.0,
#  'Na': 13.87,
#  'RI': 1.51556,
#  'Si': 73.23,
#  'index': 197}
# {'Al': 2.34,
#  'Ba': 0.66,
#  'Ca': 8.95,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.7,
#  'RI': 1.5172700000000001,
#  'Si': 73.28,
#  'index': 198}
# {'Al': 2.66,
#  'Ba': 0.64,
#  'Ca': 9.08,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.04,
#  'Mg': 0.0,
#  'Na': 14.38,
#  'RI': 1.51531,
#  'Si': 73.1,
#  'index': 199}
# {'Al': 2.51,
#  'Ba': 0.53,
#  'Ca': 8.83,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.05,
#  'Mg': 0.0,
#  'Na': 15.01,
#  'RI': 1.51609,
#  'Si': 73.05,
#  'index': 200}
# {'Al': 2.25,
#  'Ba': 0.63,
#  'Ca': 8.34,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 15.15,
#  'RI': 1.51508,
#  'Si': 73.5,
#  'index': 201}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.93,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 2.7,
#  'Mg': 0.0,
#  'Na': 11.95,
#  'RI': 1.51653,
#  'Si': 75.18,
#  'index': 202}
# {'Al': 2.42,
#  'Ba': 0.56,
#  'Ca': 8.39,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.85,
#  'RI': 1.51514,
#  'Si': 73.72,
#  'index': 203}
# {'Al': 1.99,
#  'Ba': 1.71,
#  'Ca': 8.28,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.8,
#  'RI': 1.5165799999999998,
#  'Si': 73.11,
#  'index': 204}
# {'Al': 2.27,
#  'Ba': 0.67,
#  'Ca': 8.71,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.95,
#  'RI': 1.51617,
#  'Si': 73.3,
#  'index': 205}
# {'Al': 1.8,
#  'Ba': 1.55,
#  'Ca': 8.61,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.95,
#  'RI': 1.51732,
#  'Si': 72.99,
#  'index': 206}
# {'Al': 1.87,
#  'Ba': 1.38,
#  'Ca': 8.67,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.94,
#  'RI': 1.51645,
#  'Si': 73.11,
#  'index': 207}
# {'Al': 1.82,
#  'Ba': 2.88,
#  'Ca': 6.47,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 1.41,
#  'Mg': 0.0,
#  'Na': 14.39,
#  'RI': 1.51831,
#  'Si': 72.86,
#  'index': 208}
# {'Al': 2.74,
#  'Ba': 0.54,
#  'Ca': 9.45,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.37,
#  'RI': 1.5164,
#  'Si': 72.85,
#  'index': 209}
# {'Al': 2.88,
#  'Ba': 1.06,
#  'Ca': 9.18,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.08,
#  'Mg': 0.0,
#  'Na': 14.14,
#  'RI': 1.51623,
#  'Si': 72.61,
#  'index': 210}
# {'Al': 1.99,
#  'Ba': 1.59,
#  'Ca': 8.4,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.92,
#  'RI': 1.51685,
#  'Si': 73.06,
#  'index': 211}
# {'Al': 2.02,
#  'Ba': 1.64,
#  'Ca': 8.44,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.36,
#  'RI': 1.52065,
#  'Si': 73.42,
#  'index': 212}
# {'Al': 1.94,
#  'Ba': 1.57,
#  'Ca': 8.48,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.38,
#  'RI': 1.51651,
#  'Si': 73.61,
#  'index': 213}
# {'Al': 2.08,
#  'Ba': 1.67,
#  'Ca': 8.62,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.23,
#  'RI': 1.51711,
#  'Si': 73.36,
#  'index': 214}

# %%
import pymongo

# %%
# establishing connection with mongodb cluster
# enter your mongodb cluster connection link in the cluster variable
cluster = "mongodb+srv://<id>:<password>@cluster0.2hdi0a7.mongodb.net/?retryWrites=true&w=majority"
client = pymongo.MongoClient(cluster)
db_list = client.list_database_names()
print(db_list)
# Out:
# ['glass_db', 'new', 'production', 'admin', 'local']

# %%
if "glass_db" in db_list:
    print('Database glass_db available')
    glass_db = client.glass_db
    print("selecting existing database glass_db")
else:
    print("Database glass_db not available")
    glass_db = client.glass_db
    print("Created database glass_db")
# Out:
# Database glass_db available
# selecting existing database glass_db

# %%
glass_db.list_collection_names()
# Out:
# ['glass_collection']

# %%
if 'glass_collection'in glass_db.list_collection_names():
    glass_db.glass_collection.drop()
    print('Dropped glass_connection')

print("recreating glass_collection.....")
glass_collection = glass_db.glass_collection
print("glass_collection recreated !")
# Out:
# Dropped glass_connection
# recreating glass_collection.....
# glass_collection recreated !

# %%
# inserting glass data into a collection
glass_collection.insert_many(glass_dict)

# %%
for i in glass_collection.find():
    printer.pprint(i)
# Out:
# {'Al': 1.1,
#  'Ba': 0.0,
#  'Ca': 8.75,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 4.49,
#  'Na': 13.64,
#  'RI': 1.52101,
#  'Si': 71.78,
#  '_id': ObjectId('63c556af17b2c42673cd40cc'),
#  'index': 1}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 7.83,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.48,
#  'Mg': 3.6,
#  'Na': 13.89,
#  'RI': 1.5176100000000001,
#  'Si': 72.73,
#  '_id': ObjectId('63c556af17b2c42673cd40cd'),
#  'index': 2}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.78,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.39,
#  'Mg': 3.55,
#  'Na': 13.53,
#  'RI': 1.5161799999999999,
#  'Si': 72.99,
#  '_id': ObjectId('63c556af17b2c42673cd40ce'),
#  'index': 3}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 8.22,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.69,
#  'Na': 13.21,
#  'RI': 1.51766,
#  'Si': 72.61,
#  '_id': ObjectId('63c556af17b2c42673cd40cf'),
#  'index': 4}
# {'Al': 1.24,
#  'Ba': 0.0,
#  'Ca': 8.07,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 3.62,
#  'Na': 13.27,
#  'RI': 1.51742,
#  'Si': 73.08,
#  '_id': ObjectId('63c556af17b2c42673cd40d0'),
#  'index': 5}
# {'Al': 1.62,
#  'Ba': 0.0,
#  'Ca': 8.07,
#  'Class': 1,
#  'Fe': 0.26,
#  'K': 0.64,
#  'Mg': 3.61,
#  'Na': 12.79,
#  'RI': 1.51596,
#  'Si': 72.97,
#  '_id': ObjectId('63c556af17b2c42673cd40d1'),
#  'index': 6}
# {'Al': 1.14,
#  'Ba': 0.0,
#  'Ca': 8.17,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.6,
#  'Na': 13.3,
#  'RI': 1.5174299999999998,
#  'Si': 73.09,
#  '_id': ObjectId('63c556af17b2c42673cd40d2'),
#  'index': 7}
# {'Al': 1.05,
#  'Ba': 0.0,
#  'Ca': 8.24,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.61,
#  'Na': 13.15,
#  'RI': 1.51756,
#  'Si': 73.24,
#  '_id': ObjectId('63c556af17b2c42673cd40d3'),
#  'index': 8}
# {'Al': 1.37,
#  'Ba': 0.0,
#  'Ca': 8.3,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.58,
#  'Na': 14.04,
#  'RI': 1.51918,
#  'Si': 72.08,
#  '_id': ObjectId('63c556af17b2c42673cd40d4'),
#  'index': 9}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 8.4,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.57,
#  'Mg': 3.6,
#  'Na': 13.0,
#  'RI': 1.51755,
#  'Si': 72.99,
#  '_id': ObjectId('63c556af17b2c42673cd40d5'),
#  'index': 10}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 8.09,
#  'Class': 1,
#  'Fe': 0.24,
#  'K': 0.67,
#  'Mg': 3.46,
#  'Na': 12.72,
#  'RI': 1.5157100000000001,
#  'Si': 73.2,
#  '_id': ObjectId('63c556af17b2c42673cd40d6'),
#  'index': 11}
# {'Al': 1.27,
#  'Ba': 0.0,
#  'Ca': 8.56,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.66,
#  'Na': 12.8,
#  'RI': 1.51763,
#  'Si': 73.01,
#  '_id': ObjectId('63c556af17b2c42673cd40d7'),
#  'index': 12}
# {'Al': 1.4,
#  'Ba': 0.0,
#  'Ca': 8.05,
#  'Class': 1,
#  'Fe': 0.24,
#  'K': 0.69,
#  'Mg': 3.43,
#  'Na': 12.88,
#  'RI': 1.51589,
#  'Si': 73.28,
#  '_id': ObjectId('63c556af17b2c42673cd40d8'),
#  'index': 13}
# {'Al': 1.27,
#  'Ba': 0.0,
#  'Ca': 8.38,
#  'Class': 1,
#  'Fe': 0.17,
#  'K': 0.54,
#  'Mg': 3.56,
#  'Na': 12.86,
#  'RI': 1.51748,
#  'Si': 73.21,
#  '_id': ObjectId('63c556af17b2c42673cd40d9'),
#  'index': 14}
# {'Al': 1.31,
#  'Ba': 0.0,
#  'Ca': 8.5,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.59,
#  'Na': 12.61,
#  'RI': 1.51763,
#  'Si': 73.29,
#  '_id': ObjectId('63c556af17b2c42673cd40da'),
#  'index': 15}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.39,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.54,
#  'Na': 12.81,
#  'RI': 1.5176100000000001,
#  'Si': 73.24,
#  '_id': ObjectId('63c556af17b2c42673cd40db'),
#  'index': 16}
# {'Al': 1.16,
#  'Ba': 0.0,
#  'Ca': 8.7,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.67,
#  'Na': 12.68,
#  'RI': 1.5178399999999999,
#  'Si': 73.11,
#  '_id': ObjectId('63c556af17b2c42673cd40dc'),
#  'index': 17}
# {'Al': 0.89,
#  'Ba': 0.0,
#  'Ca': 9.15,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.15,
#  'Mg': 3.85,
#  'Na': 14.36,
#  'RI': 1.52196,
#  'Si': 71.36,
#  '_id': ObjectId('63c556af17b2c42673cd40dd'),
#  'index': 18}
# {'Al': 1.18,
#  'Ba': 0.0,
#  'Ca': 8.89,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 3.73,
#  'Na': 13.9,
#  'RI': 1.51911,
#  'Si': 72.12,
#  '_id': ObjectId('63c556af17b2c42673cd40de'),
#  'index': 19}
# {'Al': 1.69,
#  'Ba': 0.0,
#  'Ca': 8.44,
#  'Class': 1,
#  'Fe': 0.07,
#  'K': 0.54,
#  'Mg': 3.54,
#  'Na': 13.02,
#  'RI': 1.51735,
#  'Si': 72.73,
#  '_id': ObjectId('63c556af17b2c42673cd40df'),
#  'index': 20}
# {'Al': 1.49,
#  'Ba': 0.0,
#  'Ca': 8.52,
#  'Class': 1,
#  'Fe': 0.19,
#  'K': 0.54,
#  'Mg': 3.55,
#  'Na': 12.82,
#  'RI': 1.5175,
#  'Si': 72.75,
#  '_id': ObjectId('63c556af17b2c42673cd40e0'),
#  'index': 21}
# {'Al': 0.29,
#  'Ba': 0.0,
#  'Ca': 9.0,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.03,
#  'Mg': 3.75,
#  'Na': 14.77,
#  'RI': 1.51966,
#  'Si': 72.02,
#  '_id': ObjectId('63c556af17b2c42673cd40e1'),
#  'index': 22}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 8.7,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.62,
#  'Na': 12.78,
#  'RI': 1.51736,
#  'Si': 72.79,
#  '_id': ObjectId('63c556af17b2c42673cd40e2'),
#  'index': 23}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 8.59,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.62,
#  'Mg': 3.57,
#  'Na': 12.81,
#  'RI': 1.5175100000000001,
#  'Si': 73.02,
#  '_id': ObjectId('63c556af17b2c42673cd40e3'),
#  'index': 24}
# {'Al': 1.15,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.5,
#  'Mg': 3.5,
#  'Na': 13.38,
#  'RI': 1.5172,
#  'Si': 72.85,
#  '_id': ObjectId('63c556af17b2c42673cd40e4'),
#  'index': 25}
# {'Al': 1.21,
#  'Ba': 0.0,
#  'Ca': 8.53,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.65,
#  'Mg': 3.54,
#  'Na': 12.98,
#  'RI': 1.5176399999999999,
#  'Si': 73.0,
#  '_id': ObjectId('63c556af17b2c42673cd40e5'),
#  'index': 26}
# {'Al': 1.41,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.48,
#  'Na': 13.21,
#  'RI': 1.51793,
#  'Si': 72.64,
#  '_id': ObjectId('63c556af17b2c42673cd40e6'),
#  'index': 27}
# {'Al': 1.33,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.48,
#  'Na': 12.87,
#  'RI': 1.51721,
#  'Si': 73.04,
#  '_id': ObjectId('63c556af17b2c42673cd40e7'),
#  'index': 28}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 8.54,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.52,
#  'Na': 12.56,
#  'RI': 1.51768,
#  'Si': 73.15,
#  '_id': ObjectId('63c556af17b2c42673cd40e8'),
#  'index': 29}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 8.49,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.49,
#  'Na': 13.08,
#  'RI': 1.5178399999999999,
#  'Si': 72.86,
#  '_id': ObjectId('63c556af17b2c42673cd40e9'),
#  'index': 30}
# {'Al': 1.3,
#  'Ba': 0.0,
#  'Ca': 8.69,
#  'Class': 1,
#  'Fe': 0.14,
#  'K': 0.61,
#  'Mg': 3.56,
#  'Na': 12.65,
#  'RI': 1.51768,
#  'Si': 73.08,
#  '_id': ObjectId('63c556af17b2c42673cd40ea'),
#  'index': 31}
# {'Al': 1.14,
#  'Ba': 0.0,
#  'Ca': 8.55,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.5,
#  'Na': 12.84,
#  'RI': 1.51747,
#  'Si': 73.27,
#  '_id': ObjectId('63c556af17b2c42673cd40eb'),
#  'index': 32}
# {'Al': 1.23,
#  'Ba': 0.09,
#  'Ca': 8.56,
#  'Class': 1,
#  'Fe': 0.22,
#  'K': 0.61,
#  'Mg': 3.48,
#  'Na': 12.85,
#  'RI': 1.51775,
#  'Si': 72.97,
#  '_id': ObjectId('63c556af17b2c42673cd40ec'),
#  'index': 33}
# {'Al': 1.38,
#  'Ba': 0.0,
#  'Ca': 8.55,
#  'Class': 1,
#  'Fe': 0.06,
#  'K': 0.6,
#  'Mg': 3.47,
#  'Na': 12.57,
#  'RI': 1.5175299999999998,
#  'Si': 73.39,
#  '_id': ObjectId('63c556af17b2c42673cd40ed'),
#  'index': 34}
# {'Al': 1.34,
#  'Ba': 0.0,
#  'Ca': 8.75,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.54,
#  'Na': 12.69,
#  'RI': 1.51783,
#  'Si': 72.95,
#  '_id': ObjectId('63c556af17b2c42673cd40ee'),
#  'index': 35}
# {'Al': 1.21,
#  'Ba': 0.0,
#  'Ca': 8.57,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.45,
#  'Na': 13.29,
#  'RI': 1.51567,
#  'Si': 72.74,
#  '_id': ObjectId('63c556af17b2c42673cd40ef'),
#  'index': 36}
# {'Al': 1.32,
#  'Ba': 0.11,
#  'Ca': 8.78,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.51,
#  'Mg': 3.53,
#  'Na': 13.89,
#  'RI': 1.51909,
#  'Si': 71.81,
#  '_id': ObjectId('63c556af17b2c42673cd40f0'),
#  'index': 37}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 8.68,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.48,
#  'Na': 12.74,
#  'RI': 1.51797,
#  'Si': 72.96,
#  '_id': ObjectId('63c556af17b2c42673cd40f1'),
#  'index': 38}
# {'Al': 0.47,
#  'Ba': 0.0,
#  'Ca': 9.57,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.82,
#  'Na': 14.21,
#  'RI': 1.52213,
#  'Si': 71.77,
#  '_id': ObjectId('63c556af17b2c42673cd40f2'),
#  'index': 39}
# {'Al': 0.47,
#  'Ba': 0.0,
#  'Ca': 9.57,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.82,
#  'Na': 14.21,
#  'RI': 1.52213,
#  'Si': 71.77,
#  '_id': ObjectId('63c556af17b2c42673cd40f3'),
#  'index': 40}
# {'Al': 1.12,
#  'Ba': 0.0,
#  'Ca': 8.77,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.5,
#  'Na': 12.79,
#  'RI': 1.51793,
#  'Si': 73.03,
#  '_id': ObjectId('63c556af17b2c42673cd40f4'),
#  'index': 41}
# {'Al': 1.2,
#  'Ba': 0.0,
#  'Ca': 8.64,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.42,
#  'Na': 12.71,
#  'RI': 1.51755,
#  'Si': 73.2,
#  '_id': ObjectId('63c556af17b2c42673cd40f5'),
#  'index': 42}
# {'Al': 1.33,
#  'Ba': 0.0,
#  'Ca': 8.59,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.39,
#  'Na': 13.21,
#  'RI': 1.51779,
#  'Si': 72.76,
#  '_id': ObjectId('63c556af17b2c42673cd40f6'),
#  'index': 43}
# {'Al': 0.72,
#  'Ba': 0.0,
#  'Ca': 9.74,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.17,
#  'Mg': 3.84,
#  'Na': 13.73,
#  'RI': 1.5221,
#  'Si': 71.76,
#  '_id': ObjectId('63c556af17b2c42673cd40f7'),
#  'index': 44}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.76,
#  'Class': 1,
#  'Fe': 0.3,
#  'K': 0.62,
#  'Mg': 3.43,
#  'Na': 12.73,
#  'RI': 1.51786,
#  'Si': 72.95,
#  '_id': ObjectId('63c556af17b2c42673cd40f8'),
#  'index': 45}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 9.0,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 3.48,
#  'Na': 13.49,
#  'RI': 1.519,
#  'Si': 71.95,
#  '_id': ObjectId('63c556af17b2c42673cd40f9'),
#  'index': 46}
# {'Al': 1.18,
#  'Ba': 0.0,
#  'Ca': 8.83,
#  'Class': 1,
#  'Fe': 0.16,
#  'K': 0.57,
#  'Mg': 3.37,
#  'Na': 13.19,
#  'RI': 1.5186899999999999,
#  'Si': 72.72,
#  '_id': ObjectId('63c556af17b2c42673cd40fa'),
#  'index': 47}
# {'Al': 0.71,
#  'Ba': 0.0,
#  'Ca': 9.82,
#  'Class': 1,
#  'Fe': 0.1,
#  'K': 0.02,
#  'Mg': 3.7,
#  'Na': 13.99,
#  'RI': 1.52667,
#  'Si': 71.57,
#  '_id': ObjectId('63c556af17b2c42673cd40fb'),
#  'index': 48}
# {'Al': 0.79,
#  'Ba': 0.0,
#  'Ca': 10.02,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.13,
#  'Mg': 3.77,
#  'Na': 13.21,
#  'RI': 1.52223,
#  'Si': 71.99,
#  '_id': ObjectId('63c556af17b2c42673cd40fc'),
#  'index': 49}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.91,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.35,
#  'Na': 13.58,
#  'RI': 1.51898,
#  'Si': 72.08,
#  '_id': ObjectId('63c556af17b2c42673cd40fd'),
#  'index': 50}
# {'Al': 0.51,
#  'Ba': 0.0,
#  'Ca': 10.06,
#  'Class': 1,
#  'Fe': 0.16,
#  'K': 0.09,
#  'Mg': 3.72,
#  'Na': 13.72,
#  'RI': 1.5232,
#  'Si': 71.75,
#  '_id': ObjectId('63c556af17b2c42673cd40fe'),
#  'index': 51}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 9.14,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.6,
#  'Mg': 3.33,
#  'Na': 13.2,
#  'RI': 1.51926,
#  'Si': 72.36,
#  '_id': ObjectId('63c556af17b2c42673cd40ff'),
#  'index': 52}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 9.03,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 2.87,
#  'Na': 13.43,
#  'RI': 1.5180799999999999,
#  'Si': 72.84,
#  '_id': ObjectId('63c556af17b2c42673cd4100'),
#  'index': 53}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 9.07,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.55,
#  'Mg': 2.84,
#  'Na': 13.14,
#  'RI': 1.51837,
#  'Si': 72.85,
#  '_id': ObjectId('63c556af17b2c42673cd4101'),
#  'index': 54}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 9.02,
#  'Class': 1,
#  'Fe': 0.09,
#  'K': 0.51,
#  'Mg': 2.81,
#  'Na': 13.21,
#  'RI': 1.51778,
#  'Si': 72.98,
#  '_id': ObjectId('63c556af17b2c42673cd4102'),
#  'index': 55}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 9.06,
#  'Class': 1,
#  'Fe': 0.24,
#  'K': 0.56,
#  'Mg': 2.71,
#  'Na': 12.45,
#  'RI': 1.51769,
#  'Si': 73.7,
#  '_id': ObjectId('63c556af17b2c42673cd4103'),
#  'index': 56}
# {'Al': 1.12,
#  'Ba': 0.0,
#  'Ca': 8.35,
#  'Class': 1,
#  'Fe': 0.31,
#  'K': 0.62,
#  'Mg': 3.47,
#  'Na': 12.99,
#  'RI': 1.51215,
#  'Si': 72.98,
#  '_id': ObjectId('63c556af17b2c42673cd4104'),
#  'index': 57}
# {'Al': 1.29,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.48,
#  'Na': 12.87,
#  'RI': 1.51824,
#  'Si': 72.95,
#  '_id': ObjectId('63c556af17b2c42673cd4105'),
#  'index': 58}
# {'Al': 1.17,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.74,
#  'Na': 13.48,
#  'RI': 1.51754,
#  'Si': 72.99,
#  '_id': ObjectId('63c556af17b2c42673cd4106'),
#  'index': 59}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.27,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.57,
#  'Mg': 3.66,
#  'Na': 13.39,
#  'RI': 1.51754,
#  'Si': 72.79,
#  '_id': ObjectId('63c556af17b2c42673cd4107'),
#  'index': 60}
# {'Al': 1.11,
#  'Ba': 0.0,
#  'Ca': 8.76,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.14,
#  'Mg': 3.62,
#  'Na': 13.6,
#  'RI': 1.51905,
#  'Si': 72.64,
#  '_id': ObjectId('63c556af17b2c42673cd4108'),
#  'index': 61}
# {'Al': 1.32,
#  'Ba': 0.69,
#  'Ca': 8.67,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.12,
#  'Mg': 3.58,
#  'Na': 13.81,
#  'RI': 1.51977,
#  'Si': 71.72,
#  '_id': ObjectId('63c556af17b2c42673cd4109'),
#  'index': 62}
# {'Al': 0.88,
#  'Ba': 0.0,
#  'Ca': 9.54,
#  'Class': 1,
#  'Fe': 0.11,
#  'K': 0.23,
#  'Mg': 3.86,
#  'Na': 13.51,
#  'RI': 1.5217200000000002,
#  'Si': 71.79,
#  '_id': ObjectId('63c556af17b2c42673cd410a'),
#  'index': 63}
# {'Al': 0.78,
#  'Ba': 0.0,
#  'Ca': 9.69,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 3.81,
#  'Na': 14.17,
#  'RI': 1.52227,
#  'Si': 71.35,
#  '_id': ObjectId('63c556af17b2c42673cd410b'),
#  'index': 64}
# {'Al': 0.9,
#  'Ba': 0.0,
#  'Ca': 9.61,
#  'Class': 1,
#  'Fe': 0.07,
#  'K': 0.18,
#  'Mg': 3.74,
#  'Na': 13.48,
#  'RI': 1.5217200000000002,
#  'Si': 72.01,
#  '_id': ObjectId('63c556af17b2c42673cd410c'),
#  'index': 65}
# {'Al': 1.12,
#  'Ba': 0.0,
#  'Ca': 9.4,
#  'Class': 1,
#  'Fe': 0.0,
#  'K': 0.09,
#  'Mg': 3.59,
#  'Na': 13.69,
#  'RI': 1.52099,
#  'Si': 71.96,
#  '_id': ObjectId('63c556af17b2c42673cd410d'),
#  'index': 66}
# {'Al': 0.87,
#  'Ba': 0.0,
#  'Ca': 9.85,
#  'Class': 1,
#  'Fe': 0.17,
#  'K': 0.19,
#  'Mg': 3.65,
#  'Na': 13.05,
#  'RI': 1.52152,
#  'Si': 72.22,
#  '_id': ObjectId('63c556af17b2c42673cd410e'),
#  'index': 67}
# {'Al': 0.87,
#  'Ba': 0.0,
#  'Ca': 9.85,
#  'Class': 1,
#  'Fe': 0.17,
#  'K': 0.19,
#  'Mg': 3.65,
#  'Na': 13.05,
#  'RI': 1.52152,
#  'Si': 72.32,
#  '_id': ObjectId('63c556af17b2c42673cd410f'),
#  'index': 68}
# {'Al': 0.9,
#  'Ba': 0.0,
#  'Ca': 9.82,
#  'Class': 1,
#  'Fe': 0.16,
#  'K': 0.23,
#  'Mg': 3.58,
#  'Na': 13.12,
#  'RI': 1.52152,
#  'Si': 72.2,
#  '_id': ObjectId('63c556af17b2c42673cd4110'),
#  'index': 69}
# {'Al': 0.82,
#  'Ba': 0.0,
#  'Ca': 10.17,
#  'Class': 1,
#  'Fe': 0.03,
#  'K': 0.12,
#  'Mg': 3.58,
#  'Na': 13.31,
#  'RI': 1.523,
#  'Si': 71.99,
#  '_id': ObjectId('63c556af17b2c42673cd4111'),
#  'index': 70}
# {'Al': 1.74,
#  'Ba': 0.0,
#  'Ca': 7.36,
#  'Class': 2,
#  'Fe': 0.12,
#  'K': 0.16,
#  'Mg': 3.67,
#  'Na': 14.86,
#  'RI': 1.5157399999999999,
#  'Si': 71.87,
#  '_id': ObjectId('63c556af17b2c42673cd4112'),
#  'index': 71}
# {'Al': 1.27,
#  'Ba': 0.0,
#  'Ca': 8.32,
#  'Class': 2,
#  'Fe': 0.32,
#  'K': 0.54,
#  'Mg': 3.87,
#  'Na': 13.64,
#  'RI': 1.5184799999999998,
#  'Si': 71.96,
#  '_id': ObjectId('63c556af17b2c42673cd4113'),
#  'index': 72}
# {'Al': 1.52,
#  'Ba': 0.0,
#  'Ca': 7.83,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.67,
#  'Mg': 3.59,
#  'Na': 13.09,
#  'RI': 1.51593,
#  'Si': 73.1,
#  '_id': ObjectId('63c556af17b2c42673cd4114'),
#  'index': 73}
# {'Al': 1.57,
#  'Ba': 0.0,
#  'Ca': 7.89,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.57,
#  'Na': 13.34,
#  'RI': 1.51631,
#  'Si': 72.87,
#  '_id': ObjectId('63c556af17b2c42673cd4115'),
#  'index': 74}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.9,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.72,
#  'Mg': 3.56,
#  'Na': 13.02,
#  'RI': 1.51596,
#  'Si': 73.11,
#  '_id': ObjectId('63c556af17b2c42673cd4116'),
#  'index': 75}
# {'Al': 1.51,
#  'Ba': 0.0,
#  'Ca': 7.96,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.69,
#  'Mg': 3.58,
#  'Na': 13.02,
#  'RI': 1.5159,
#  'Si': 73.12,
#  '_id': ObjectId('63c556af17b2c42673cd4117'),
#  'index': 76}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.66,
#  'Mg': 3.61,
#  'Na': 13.44,
#  'RI': 1.51645,
#  'Si': 72.39,
#  '_id': ObjectId('63c556af17b2c42673cd4118'),
#  'index': 77}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.04,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.58,
#  'Na': 13.0,
#  'RI': 1.51627,
#  'Si': 72.83,
#  '_id': ObjectId('63c556af17b2c42673cd4119'),
#  'index': 78}
# {'Al': 1.25,
#  'Ba': 0.0,
#  'Ca': 7.94,
#  'Class': 2,
#  'Fe': 0.14,
#  'K': 0.37,
#  'Mg': 3.52,
#  'Na': 13.92,
#  'RI': 1.51613,
#  'Si': 72.88,
#  '_id': ObjectId('63c556af17b2c42673cd411a'),
#  'index': 79}
# {'Al': 1.9,
#  'Ba': 0.0,
#  'Ca': 7.97,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.69,
#  'Mg': 3.52,
#  'Na': 12.82,
#  'RI': 1.5159,
#  'Si': 72.86,
#  '_id': ObjectId('63c556af17b2c42673cd411b'),
#  'index': 80}
# {'Al': 2.12,
#  'Ba': 0.0,
#  'Ca': 7.97,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.69,
#  'Mg': 3.52,
#  'Na': 12.86,
#  'RI': 1.5159200000000002,
#  'Si': 72.66,
#  '_id': ObjectId('63c556af17b2c42673cd411c'),
#  'index': 81}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 7.86,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.45,
#  'Na': 13.25,
#  'RI': 1.51593,
#  'Si': 73.17,
#  '_id': ObjectId('63c556af17b2c42673cd411d'),
#  'index': 82}
# {'Al': 1.25,
#  'Ba': 0.0,
#  'Ca': 8.1,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.68,
#  'Mg': 3.55,
#  'Na': 13.41,
#  'RI': 1.5164600000000001,
#  'Si': 72.81,
#  '_id': ObjectId('63c556af17b2c42673cd411e'),
#  'index': 83}
# {'Al': 1.55,
#  'Ba': 0.0,
#  'Ca': 8.05,
#  'Class': 2,
#  'Fe': 0.09,
#  'K': 0.68,
#  'Mg': 3.52,
#  'Na': 13.09,
#  'RI': 1.51594,
#  'Si': 72.87,
#  '_id': ObjectId('63c556af17b2c42673cd411f'),
#  'index': 84}
# {'Al': 2.08,
#  'Ba': 0.0,
#  'Ca': 7.08,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 1.1,
#  'Mg': 3.09,
#  'Na': 14.25,
#  'RI': 1.51409,
#  'Si': 72.28,
#  '_id': ObjectId('63c556af17b2c42673cd4120'),
#  'index': 85}
# {'Al': 1.49,
#  'Ba': 0.0,
#  'Ca': 8.21,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.45,
#  'Mg': 3.58,
#  'Na': 13.36,
#  'RI': 1.51625,
#  'Si': 72.72,
#  '_id': ObjectId('63c556af17b2c42673cd4121'),
#  'index': 86}
# {'Al': 1.47,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.38,
#  'Mg': 3.49,
#  'Na': 13.24,
#  'RI': 1.51569,
#  'Si': 73.25,
#  '_id': ObjectId('63c556af17b2c42673cd4122'),
#  'index': 87}
# {'Al': 1.52,
#  'Ba': 0.0,
#  'Ca': 8.08,
#  'Class': 2,
#  'Fe': 0.1,
#  'K': 0.67,
#  'Mg': 3.49,
#  'Na': 13.4,
#  'RI': 1.51645,
#  'Si': 72.65,
#  '_id': ObjectId('63c556af17b2c42673cd4123'),
#  'index': 88}
# {'Al': 1.48,
#  'Ba': 0.0,
#  'Ca': 8.12,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.5,
#  'Na': 13.01,
#  'RI': 1.5161799999999999,
#  'Si': 72.89,
#  '_id': ObjectId('63c556af17b2c42673cd4124'),
#  'index': 89}
# {'Al': 1.87,
#  'Ba': 0.0,
#  'Ca': 8.08,
#  'Class': 2,
#  'Fe': 0.09,
#  'K': 0.63,
#  'Mg': 3.48,
#  'Na': 12.55,
#  'RI': 1.5164,
#  'Si': 73.23,
#  '_id': ObjectId('63c556af17b2c42673cd4125'),
#  'index': 90}
# {'Al': 1.11,
#  'Ba': 0.0,
#  'Ca': 8.96,
#  'Class': 2,
#  'Fe': 0.22,
#  'K': 0.64,
#  'Mg': 3.74,
#  'Na': 12.93,
#  'RI': 1.51841,
#  'Si': 72.28,
#  '_id': ObjectId('63c556af17b2c42673cd4126'),
#  'index': 91}
# {'Al': 1.45,
#  'Ba': 0.0,
#  'Ca': 8.27,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.44,
#  'Mg': 3.44,
#  'Na': 12.9,
#  'RI': 1.51605,
#  'Si': 73.06,
#  '_id': ObjectId('63c556af17b2c42673cd4127'),
#  'index': 92}
# {'Al': 1.58,
#  'Ba': 0.0,
#  'Ca': 8.39,
#  'Class': 2,
#  'Fe': 0.19,
#  'K': 0.07,
#  'Mg': 3.41,
#  'Na': 13.12,
#  'RI': 1.51588,
#  'Si': 73.26,
#  '_id': ObjectId('63c556af17b2c42673cd4128'),
#  'index': 93}
# {'Al': 1.47,
#  'Ba': 0.0,
#  'Ca': 8.22,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.39,
#  'Mg': 3.34,
#  'Na': 13.24,
#  'RI': 1.5159,
#  'Si': 73.1,
#  '_id': ObjectId('63c556af17b2c42673cd4129'),
#  'index': 94}
# {'Al': 1.49,
#  'Ba': 0.0,
#  'Ca': 8.24,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.67,
#  'Mg': 3.33,
#  'Na': 12.71,
#  'RI': 1.51629,
#  'Si': 73.28,
#  '_id': ObjectId('63c556af17b2c42673cd412a'),
#  'index': 95}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 8.6,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.51,
#  'Mg': 3.43,
#  'Na': 13.36,
#  'RI': 1.5186,
#  'Si': 72.26,
#  '_id': ObjectId('63c556af17b2c42673cd412b'),
#  'index': 96}
# {'Al': 1.06,
#  'Ba': 0.0,
#  'Ca': 9.13,
#  'Class': 2,
#  'Fe': 0.15,
#  'K': 0.64,
#  'Mg': 3.62,
#  'Na': 13.02,
#  'RI': 1.51841,
#  'Si': 72.34,
#  '_id': ObjectId('63c556af17b2c42673cd412c'),
#  'index': 97}
# {'Al': 1.16,
#  'Ba': 0.0,
#  'Ca': 8.9,
#  'Class': 2,
#  'Fe': 0.24,
#  'K': 0.62,
#  'Mg': 3.25,
#  'Na': 12.2,
#  'RI': 1.5174299999999998,
#  'Si': 73.55,
#  '_id': ObjectId('63c556af17b2c42673cd412d'),
#  'index': 98}
# {'Al': 1.71,
#  'Ba': 0.0,
#  'Ca': 8.54,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.73,
#  'Mg': 2.88,
#  'Na': 12.67,
#  'RI': 1.51689,
#  'Si': 73.21,
#  '_id': ObjectId('63c556af17b2c42673cd412e'),
#  'index': 99}
# {'Al': 1.43,
#  'Ba': 0.14,
#  'Ca': 8.79,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 2.96,
#  'Na': 12.96,
#  'RI': 1.51811,
#  'Si': 72.92,
#  '_id': ObjectId('63c556af17b2c42673cd412f'),
#  'index': 100}
# {'Al': 1.44,
#  'Ba': 0.11,
#  'Ca': 8.79,
#  'Class': 2,
#  'Fe': 0.22,
#  'K': 0.57,
#  'Mg': 2.85,
#  'Na': 12.75,
#  'RI': 1.51655,
#  'Si': 73.27,
#  '_id': ObjectId('63c556af17b2c42673cd4130'),
#  'index': 101}
# {'Al': 1.63,
#  'Ba': 0.0,
#  'Ca': 9.23,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.7,
#  'Mg': 2.72,
#  'Na': 12.35,
#  'RI': 1.5173,
#  'Si': 72.87,
#  '_id': ObjectId('63c556af17b2c42673cd4131'),
#  'index': 102}
# {'Al': 0.83,
#  'Ba': 0.0,
#  'Ca': 9.42,
#  'Class': 2,
#  'Fe': 0.2,
#  'K': 0.35,
#  'Mg': 2.76,
#  'Na': 12.62,
#  'RI': 1.5182,
#  'Si': 73.81,
#  '_id': ObjectId('63c556af17b2c42673cd4132'),
#  'index': 103}
# {'Al': 0.66,
#  'Ba': 0.0,
#  'Ca': 11.64,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.08,
#  'Mg': 3.15,
#  'Na': 13.8,
#  'RI': 1.52725,
#  'Si': 70.57,
#  '_id': ObjectId('63c556af17b2c42673cd4133'),
#  'index': 104}
# {'Al': 1.17,
#  'Ba': 0.0,
#  'Ca': 10.79,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.08,
#  'Mg': 2.9,
#  'Na': 13.83,
#  'RI': 1.5241,
#  'Si': 71.15,
#  '_id': ObjectId('63c556af17b2c42673cd4134'),
#  'index': 105}
# {'Al': 1.88,
#  'Ba': 0.0,
#  'Ca': 13.24,
#  'Class': 2,
#  'Fe': 0.34,
#  'K': 0.81,
#  'Mg': 0.0,
#  'Na': 11.45,
#  'RI': 1.52475,
#  'Si': 72.19,
#  '_id': ObjectId('63c556af17b2c42673cd4135'),
#  'index': 106}
# {'Al': 2.1,
#  'Ba': 3.15,
#  'Ca': 13.3,
#  'Class': 2,
#  'Fe': 0.28,
#  'K': 0.58,
#  'Mg': 0.0,
#  'Na': 10.73,
#  'RI': 1.53125,
#  'Si': 69.81,
#  '_id': ObjectId('63c556af17b2c42673cd4136'),
#  'index': 107}
# {'Al': 1.0,
#  'Ba': 0.0,
#  'Ca': 16.19,
#  'Class': 2,
#  'Fe': 0.24,
#  'K': 0.12,
#  'Mg': 0.0,
#  'Na': 12.3,
#  'RI': 1.53393,
#  'Si': 70.16,
#  '_id': ObjectId('63c556af17b2c42673cd4137'),
#  'index': 108}
# {'Al': 1.0,
#  'Ba': 0.0,
#  'Ca': 11.52,
#  'Class': 2,
#  'Fe': 0.08,
#  'K': 0.1,
#  'Mg': 0.0,
#  'Na': 14.43,
#  'RI': 1.5222200000000001,
#  'Si': 72.67,
#  '_id': ObjectId('63c556af17b2c42673cd4138'),
#  'index': 109}
# {'Al': 0.56,
#  'Ba': 0.0,
#  'Ca': 10.99,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 13.72,
#  'RI': 1.5181799999999999,
#  'Si': 74.45,
#  '_id': ObjectId('63c556af17b2c42673cd4139'),
#  'index': 110}
# {'Al': 0.77,
#  'Ba': 0.0,
#  'Ca': 14.68,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 11.23,
#  'RI': 1.52664,
#  'Si': 73.21,
#  '_id': ObjectId('63c556af17b2c42673cd413a'),
#  'index': 111}
# {'Al': 0.75,
#  'Ba': 0.0,
#  'Ca': 14.96,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 11.02,
#  'RI': 1.52739,
#  'Si': 73.08,
#  '_id': ObjectId('63c556af17b2c42673cd413b'),
#  'index': 112}
# {'Al': 0.67,
#  'Ba': 0.0,
#  'Ca': 14.4,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 0.0,
#  'Na': 12.64,
#  'RI': 1.52777,
#  'Si': 72.02,
#  '_id': ObjectId('63c556af17b2c42673cd413c'),
#  'index': 113}
# {'Al': 1.26,
#  'Ba': 0.0,
#  'Ca': 8.21,
#  'Class': 2,
#  'Fe': 0.14,
#  'K': 0.57,
#  'Mg': 3.83,
#  'Na': 13.46,
#  'RI': 1.51892,
#  'Si': 72.55,
#  '_id': ObjectId('63c556af17b2c42673cd413d'),
#  'index': 114}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.43,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.97,
#  'Na': 13.1,
#  'RI': 1.51847,
#  'Si': 72.44,
#  '_id': ObjectId('63c556af17b2c42673cd413e'),
#  'index': 115}
# {'Al': 1.33,
#  'Ba': 0.0,
#  'Ca': 8.28,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.51,
#  'Mg': 3.89,
#  'Na': 13.41,
#  'RI': 1.5184600000000001,
#  'Si': 72.38,
#  '_id': ObjectId('63c556af17b2c42673cd413f'),
#  'index': 116}
# {'Al': 1.41,
#  'Ba': 0.0,
#  'Ca': 8.31,
#  'Class': 2,
#  'Fe': 0.1,
#  'K': 0.55,
#  'Mg': 3.9,
#  'Na': 13.24,
#  'RI': 1.51829,
#  'Si': 72.33,
#  '_id': ObjectId('63c556af17b2c42673cd4140'),
#  'index': 117}
# {'Al': 1.81,
#  'Ba': 0.0,
#  'Ca': 7.88,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.68,
#  'Na': 13.72,
#  'RI': 1.51708,
#  'Si': 72.06,
#  '_id': ObjectId('63c556af17b2c42673cd4141'),
#  'index': 118}
# {'Al': 1.53,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.29,
#  'K': 0.65,
#  'Mg': 3.64,
#  'Na': 13.3,
#  'RI': 1.51673,
#  'Si': 72.53,
#  '_id': ObjectId('63c556af17b2c42673cd4142'),
#  'index': 119}
# {'Al': 1.47,
#  'Ba': 0.0,
#  'Ca': 7.96,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.64,
#  'Mg': 3.57,
#  'Na': 13.56,
#  'RI': 1.51652,
#  'Si': 72.45,
#  '_id': ObjectId('63c556af17b2c42673cd4143'),
#  'index': 120}
# {'Al': 1.32,
#  'Ba': 0.0,
#  'Ca': 8.42,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.76,
#  'Na': 13.25,
#  'RI': 1.51844,
#  'Si': 72.4,
#  '_id': ObjectId('63c556af17b2c42673cd4144'),
#  'index': 121}
# {'Al': 1.62,
#  'Ba': 0.0,
#  'Ca': 8.03,
#  'Class': 2,
#  'Fe': 0.21,
#  'K': 0.64,
#  'Mg': 3.54,
#  'Na': 12.93,
#  'RI': 1.51663,
#  'Si': 72.96,
#  '_id': ObjectId('63c556af17b2c42673cd4145'),
#  'index': 122}
# {'Al': 1.48,
#  'Ba': 0.0,
#  'Ca': 8.1,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.54,
#  'Na': 13.23,
#  'RI': 1.5168700000000002,
#  'Si': 72.84,
#  '_id': ObjectId('63c556af17b2c42673cd4146'),
#  'index': 123}
# {'Al': 1.71,
#  'Ba': 0.0,
#  'Ca': 7.99,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.62,
#  'Mg': 3.48,
#  'Na': 13.48,
#  'RI': 1.5170700000000001,
#  'Si': 72.52,
#  '_id': ObjectId('63c556af17b2c42673cd4147'),
#  'index': 124}
# {'Al': 1.15,
#  'Ba': 0.0,
#  'Ca': 8.52,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.54,
#  'Mg': 3.68,
#  'Na': 13.2,
#  'RI': 1.52177,
#  'Si': 72.75,
#  '_id': ObjectId('63c556af17b2c42673cd4148'),
#  'index': 125}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 8.55,
#  'Class': 2,
#  'Fe': 0.12,
#  'K': 0.58,
#  'Mg': 3.66,
#  'Na': 12.93,
#  'RI': 1.51872,
#  'Si': 72.51,
#  '_id': ObjectId('63c556af17b2c42673cd4149'),
#  'index': 126}
# {'Al': 1.26,
#  'Ba': 0.0,
#  'Ca': 8.6,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.61,
#  'Na': 12.94,
#  'RI': 1.51667,
#  'Si': 72.75,
#  '_id': ObjectId('63c556af17b2c42673cd414a'),
#  'index': 127}
# {'Al': 1.43,
#  'Ba': 0.0,
#  'Ca': 9.85,
#  'Class': 2,
#  'Fe': 0.17,
#  'K': 0.49,
#  'Mg': 2.28,
#  'Na': 13.78,
#  'RI': 1.52081,
#  'Si': 71.99,
#  '_id': ObjectId('63c556af17b2c42673cd414b'),
#  'index': 128}
# {'Al': 1.67,
#  'Ba': 0.27,
#  'Ca': 9.57,
#  'Class': 2,
#  'Fe': 0.17,
#  'K': 0.53,
#  'Mg': 2.09,
#  'Na': 13.55,
#  'RI': 1.52068,
#  'Si': 72.18,
#  '_id': ObjectId('63c556af17b2c42673cd414c'),
#  'index': 129}
# {'Al': 1.63,
#  'Ba': 0.0,
#  'Ca': 10.56,
#  'Class': 2,
#  'Fe': 0.18,
#  'K': 0.39,
#  'Mg': 1.35,
#  'Na': 13.98,
#  'RI': 1.5202,
#  'Si': 71.76,
#  '_id': ObjectId('63c556af17b2c42673cd414d'),
#  'index': 130}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 11.14,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.33,
#  'Mg': 1.01,
#  'Na': 13.75,
#  'RI': 1.52177,
#  'Si': 72.19,
#  '_id': ObjectId('63c556af17b2c42673cd414e'),
#  'index': 131}
# {'Al': 1.36,
#  'Ba': 0.0,
#  'Ca': 13.44,
#  'Class': 2,
#  'Fe': 0.1,
#  'K': 0.19,
#  'Mg': 0.0,
#  'Na': 13.7,
#  'RI': 1.52614,
#  'Si': 71.24,
#  '_id': ObjectId('63c556af17b2c42673cd414f'),
#  'index': 132}
# {'Al': 1.18,
#  'Ba': 0.0,
#  'Ca': 8.15,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.98,
#  'Na': 13.43,
#  'RI': 1.51813,
#  'Si': 72.49,
#  '_id': ObjectId('63c556af17b2c42673cd4150'),
#  'index': 133}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.21,
#  'Class': 2,
#  'Fe': 0.15,
#  'K': 0.54,
#  'Mg': 3.93,
#  'Na': 13.71,
#  'RI': 1.518,
#  'Si': 71.81,
#  '_id': ObjectId('63c556af17b2c42673cd4151'),
#  'index': 134}
# {'Al': 1.25,
#  'Ba': 0.0,
#  'Ca': 8.12,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.52,
#  'Mg': 3.85,
#  'Na': 13.33,
#  'RI': 1.51811,
#  'Si': 72.78,
#  '_id': ObjectId('63c556af17b2c42673cd4152'),
#  'index': 135}
# {'Al': 1.3,
#  'Ba': 0.0,
#  'Ca': 8.44,
#  'Class': 2,
#  'Fe': 0.28,
#  'K': 0.55,
#  'Mg': 3.9,
#  'Na': 13.19,
#  'RI': 1.51789,
#  'Si': 72.33,
#  '_id': ObjectId('63c556af17b2c42673cd4153'),
#  'index': 136}
# {'Al': 1.08,
#  'Ba': 0.0,
#  'Ca': 8.38,
#  'Class': 2,
#  'Fe': 0.12,
#  'K': 0.56,
#  'Mg': 3.8,
#  'Na': 13.0,
#  'RI': 1.51806,
#  'Si': 73.07,
#  '_id': ObjectId('63c556af17b2c42673cd4154'),
#  'index': 137}
# {'Al': 1.57,
#  'Ba': 0.0,
#  'Ca': 8.11,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.62,
#  'Na': 12.89,
#  'RI': 1.51711,
#  'Si': 72.96,
#  '_id': ObjectId('63c556af17b2c42673cd4155'),
#  'index': 138}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.9,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.66,
#  'Mg': 3.52,
#  'Na': 12.79,
#  'RI': 1.51674,
#  'Si': 73.36,
#  '_id': ObjectId('63c556af17b2c42673cd4156'),
#  'index': 139}
# {'Al': 1.64,
#  'Ba': 0.0,
#  'Ca': 7.99,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.65,
#  'Mg': 3.56,
#  'Na': 12.87,
#  'RI': 1.51674,
#  'Si': 73.14,
#  '_id': ObjectId('63c556af17b2c42673cd4157'),
#  'index': 140}
# {'Al': 1.61,
#  'Ba': 0.0,
#  'Ca': 8.11,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.68,
#  'Mg': 3.54,
#  'Na': 13.33,
#  'RI': 1.5169,
#  'Si': 72.54,
#  '_id': ObjectId('63c556af17b2c42673cd4158'),
#  'index': 141}
# {'Al': 1.07,
#  'Ba': 0.09,
#  'Ca': 8.41,
#  'Class': 2,
#  'Fe': 0.17,
#  'K': 0.57,
#  'Mg': 3.63,
#  'Na': 13.2,
#  'RI': 1.51851,
#  'Si': 72.83,
#  '_id': ObjectId('63c556af17b2c42673cd4159'),
#  'index': 142}
# {'Al': 1.44,
#  'Ba': 0.06,
#  'Ca': 8.23,
#  'Class': 2,
#  'Fe': 0.25,
#  'K': 0.68,
#  'Mg': 3.51,
#  'Na': 12.85,
#  'RI': 1.51662,
#  'Si': 73.01,
#  '_id': ObjectId('63c556af17b2c42673cd415a'),
#  'index': 143}
# {'Al': 1.79,
#  'Ba': 0.0,
#  'Ca': 8.18,
#  'Class': 2,
#  'Fe': 0.0,
#  'K': 0.66,
#  'Mg': 3.47,
#  'Na': 13.0,
#  'RI': 1.51709,
#  'Si': 72.72,
#  '_id': ObjectId('63c556af17b2c42673cd415b'),
#  'index': 144}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.81,
#  'Class': 2,
#  'Fe': 0.24,
#  'K': 0.58,
#  'Mg': 3.18,
#  'Na': 12.99,
#  'RI': 1.5166,
#  'Si': 72.97,
#  '_id': ObjectId('63c556af17b2c42673cd415c'),
#  'index': 145}
# {'Al': 1.24,
#  'Ba': 0.0,
#  'Ca': 8.68,
#  'Class': 2,
#  'Fe': 0.35,
#  'K': 0.62,
#  'Mg': 3.67,
#  'Na': 12.85,
#  'RI': 1.51839,
#  'Si': 72.57,
#  '_id': ObjectId('63c556af17b2c42673cd415d'),
#  'index': 146}
# {'Al': 1.11,
#  'Ba': 0.0,
#  'Ca': 8.6,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.66,
#  'Na': 13.65,
#  'RI': 1.51769,
#  'Si': 72.77,
#  '_id': ObjectId('63c556af17b2c42673cd415e'),
#  'index': 147}
# {'Al': 1.34,
#  'Ba': 0.0,
#  'Ca': 8.33,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.53,
#  'Na': 13.33,
#  'RI': 1.5161,
#  'Si': 72.67,
#  '_id': ObjectId('63c556af17b2c42673cd415f'),
#  'index': 148}
# {'Al': 1.38,
#  'Ba': 0.0,
#  'Ca': 8.44,
#  'Class': 3,
#  'Fe': 0.1,
#  'K': 0.56,
#  'Mg': 3.57,
#  'Na': 13.24,
#  'RI': 1.5167,
#  'Si': 72.7,
#  '_id': ObjectId('63c556af17b2c42673cd4160'),
#  'index': 149}
# {'Al': 1.35,
#  'Ba': 0.0,
#  'Ca': 8.53,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.57,
#  'Mg': 3.52,
#  'Na': 12.16,
#  'RI': 1.51643,
#  'Si': 72.89,
#  '_id': ObjectId('63c556af17b2c42673cd4161'),
#  'index': 150}
# {'Al': 1.76,
#  'Ba': 0.0,
#  'Ca': 8.38,
#  'Class': 3,
#  'Fe': 0.17,
#  'K': 0.6,
#  'Mg': 3.45,
#  'Na': 13.14,
#  'RI': 1.51665,
#  'Si': 72.48,
#  '_id': ObjectId('63c556af17b2c42673cd4162'),
#  'index': 151}
# {'Al': 0.83,
#  'Ba': 0.0,
#  'Ca': 9.49,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 3.9,
#  'Na': 14.32,
#  'RI': 1.5212700000000001,
#  'Si': 71.5,
#  '_id': ObjectId('63c556af17b2c42673cd4163'),
#  'index': 152}
# {'Al': 0.65,
#  'Ba': 0.0,
#  'Ca': 8.93,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.06,
#  'Mg': 3.65,
#  'Na': 13.64,
#  'RI': 1.51779,
#  'Si': 73.0,
#  '_id': ObjectId('63c556af17b2c42673cd4164'),
#  'index': 153}
# {'Al': 1.22,
#  'Ba': 0.0,
#  'Ca': 8.32,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.59,
#  'Mg': 3.4,
#  'Na': 13.42,
#  'RI': 1.5161,
#  'Si': 72.69,
#  '_id': ObjectId('63c556af17b2c42673cd4165'),
#  'index': 154}
# {'Al': 1.31,
#  'Ba': 0.0,
#  'Ca': 8.79,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.61,
#  'Mg': 3.58,
#  'Na': 12.86,
#  'RI': 1.51694,
#  'Si': 72.61,
#  '_id': ObjectId('63c556af17b2c42673cd4166'),
#  'index': 155}
# {'Al': 1.26,
#  'Ba': 0.0,
#  'Ca': 8.58,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.52,
#  'Mg': 3.4,
#  'Na': 13.04,
#  'RI': 1.5164600000000001,
#  'Si': 73.01,
#  '_id': ObjectId('63c556af17b2c42673cd4167'),
#  'index': 156}
# {'Al': 1.28,
#  'Ba': 0.0,
#  'Ca': 8.65,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.52,
#  'Mg': 3.39,
#  'Na': 13.41,
#  'RI': 1.51655,
#  'Si': 72.64,
#  '_id': ObjectId('63c556af17b2c42673cd4168'),
#  'index': 157}
# {'Al': 0.58,
#  'Ba': 0.0,
#  'Ca': 9.65,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.11,
#  'Mg': 3.76,
#  'Na': 14.03,
#  'RI': 1.52121,
#  'Si': 71.79,
#  '_id': ObjectId('63c556af17b2c42673cd4169'),
#  'index': 158}
# {'Al': 1.52,
#  'Ba': 0.0,
#  'Ca': 8.79,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 3.41,
#  'Na': 13.53,
#  'RI': 1.51776,
#  'Si': 72.04,
#  '_id': ObjectId('63c556af17b2c42673cd416a'),
#  'index': 159}
# {'Al': 1.63,
#  'Ba': 0.0,
#  'Ca': 8.81,
#  'Class': 3,
#  'Fe': 0.09,
#  'K': 0.57,
#  'Mg': 3.36,
#  'Na': 13.5,
#  'RI': 1.51796,
#  'Si': 71.94,
#  '_id': ObjectId('63c556af17b2c42673cd416b'),
#  'index': 160}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 8.99,
#  'Class': 3,
#  'Fe': 0.0,
#  'K': 0.56,
#  'Mg': 3.34,
#  'Na': 13.33,
#  'RI': 1.5183200000000001,
#  'Si': 72.14,
#  '_id': ObjectId('63c556af17b2c42673cd416c'),
#  'index': 161}
# {'Al': 0.75,
#  'Ba': 0.15,
#  'Ca': 8.89,
#  'Class': 3,
#  'Fe': 0.24,
#  'K': 0.16,
#  'Mg': 3.54,
#  'Na': 13.64,
#  'RI': 1.51934,
#  'Si': 72.65,
#  '_id': ObjectId('63c556af17b2c42673cd416d'),
#  'index': 162}
# {'Al': 0.91,
#  'Ba': 0.0,
#  'Ca': 9.14,
#  'Class': 3,
#  'Fe': 0.37,
#  'K': 0.23,
#  'Mg': 3.78,
#  'Na': 14.19,
#  'RI': 1.52211,
#  'Si': 71.36,
#  '_id': ObjectId('63c556af17b2c42673cd416e'),
#  'index': 163}
# {'Al': 3.5,
#  'Ba': 2.2,
#  'Ca': 5.87,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 1.68,
#  'Mg': 2.68,
#  'Na': 14.01,
#  'RI': 1.51514,
#  'Si': 69.89,
#  '_id': ObjectId('63c556af17b2c42673cd416f'),
#  'index': 164}
# {'Al': 1.86,
#  'Ba': 0.0,
#  'Ca': 10.09,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 1.85,
#  'Na': 12.73,
#  'RI': 1.51915,
#  'Si': 72.69,
#  '_id': ObjectId('63c556af17b2c42673cd4170'),
#  'index': 165}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 11.41,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.47,
#  'Mg': 1.88,
#  'Na': 11.56,
#  'RI': 1.5217100000000001,
#  'Si': 72.86,
#  '_id': ObjectId('63c556af17b2c42673cd4171'),
#  'index': 166}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 11.62,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.58,
#  'Mg': 1.71,
#  'Na': 11.03,
#  'RI': 1.5215100000000001,
#  'Si': 73.44,
#  '_id': ObjectId('63c556af17b2c42673cd4172'),
#  'index': 167}
# {'Al': 1.65,
#  'Ba': 0.0,
#  'Ca': 11.53,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.38,
#  'Mg': 0.0,
#  'Na': 12.64,
#  'RI': 1.51969,
#  'Si': 73.75,
#  '_id': ObjectId('63c556af17b2c42673cd4173'),
#  'index': 168}
# {'Al': 1.83,
#  'Ba': 0.0,
#  'Ca': 10.17,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.97,
#  'Mg': 0.0,
#  'Na': 12.86,
#  'RI': 1.5166600000000001,
#  'Si': 73.88,
#  '_id': ObjectId('63c556af17b2c42673cd4174'),
#  'index': 169}
# {'Al': 1.76,
#  'Ba': 0.0,
#  'Ca': 11.32,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.47,
#  'Mg': 0.0,
#  'Na': 13.27,
#  'RI': 1.51994,
#  'Si': 73.03,
#  '_id': ObjectId('63c556af17b2c42673cd4175'),
#  'index': 170}
# {'Al': 1.58,
#  'Ba': 0.0,
#  'Ca': 12.24,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.32,
#  'Mg': 0.0,
#  'Na': 13.44,
#  'RI': 1.52369,
#  'Si': 72.22,
#  '_id': ObjectId('63c556af17b2c42673cd4176'),
#  'index': 171}
# {'Al': 3.04,
#  'Ba': 0.0,
#  'Ca': 6.96,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 6.21,
#  'Mg': 0.0,
#  'Na': 13.02,
#  'RI': 1.51316,
#  'Si': 70.48,
#  '_id': ObjectId('63c556af17b2c42673cd4177'),
#  'index': 172}
# {'Al': 3.02,
#  'Ba': 0.0,
#  'Ca': 6.93,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 6.21,
#  'Mg': 0.0,
#  'Na': 13.0,
#  'RI': 1.51321,
#  'Si': 70.7,
#  '_id': ObjectId('63c556af17b2c42673cd4178'),
#  'index': 173}
# {'Al': 1.4,
#  'Ba': 0.0,
#  'Ca': 12.5,
#  'Class': 5,
#  'Fe': 0.0,
#  'K': 0.33,
#  'Mg': 0.0,
#  'Na': 13.38,
#  'RI': 1.52043,
#  'Si': 72.25,
#  '_id': ObjectId('63c556af17b2c42673cd4179'),
#  'index': 174}
# {'Al': 2.17,
#  'Ba': 0.24,
#  'Ca': 9.7,
#  'Class': 5,
#  'Fe': 0.51,
#  'K': 0.76,
#  'Mg': 1.61,
#  'Na': 12.85,
#  'RI': 1.5205799999999998,
#  'Si': 72.18,
#  '_id': ObjectId('63c556af17b2c42673cd417a'),
#  'index': 175}
# {'Al': 1.51,
#  'Ba': 0.0,
#  'Ca': 11.27,
#  'Class': 5,
#  'Fe': 0.28,
#  'K': 0.13,
#  'Mg': 0.33,
#  'Na': 12.97,
#  'RI': 1.52119,
#  'Si': 73.39,
#  '_id': ObjectId('63c556af17b2c42673cd417b'),
#  'index': 176}
# {'Al': 1.56,
#  'Ba': 0.0,
#  'Ca': 9.57,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.39,
#  'Na': 14.0,
#  'RI': 1.51905,
#  'Si': 72.37,
#  '_id': ObjectId('63c556af17b2c42673cd417c'),
#  'index': 177}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 9.77,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.41,
#  'Na': 13.79,
#  'RI': 1.51937,
#  'Si': 72.76,
#  '_id': ObjectId('63c556af17b2c42673cd417d'),
#  'index': 178}
# {'Al': 1.62,
#  'Ba': 0.0,
#  'Ca': 9.26,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.24,
#  'Na': 14.46,
#  'RI': 1.51829,
#  'Si': 72.38,
#  '_id': ObjectId('63c556af17b2c42673cd417e'),
#  'index': 179}
# {'Al': 1.66,
#  'Ba': 0.0,
#  'Ca': 9.32,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 2.19,
#  'Na': 14.09,
#  'RI': 1.51852,
#  'Si': 72.67,
#  '_id': ObjectId('63c556af17b2c42673cd417f'),
#  'index': 180}
# {'Al': 1.54,
#  'Ba': 0.0,
#  'Ca': 7.59,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 1.74,
#  'Na': 14.4,
#  'RI': 1.51299,
#  'Si': 74.55,
#  '_id': ObjectId('63c556af17b2c42673cd4180'),
#  'index': 181}
# {'Al': 1.74,
#  'Ba': 0.0,
#  'Ca': 9.95,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.78,
#  'Na': 14.99,
#  'RI': 1.51888,
#  'Si': 72.5,
#  '_id': ObjectId('63c556af17b2c42673cd4181'),
#  'index': 182}
# {'Al': 2.09,
#  'Ba': 0.0,
#  'Ca': 10.88,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.15,
#  'RI': 1.51916,
#  'Si': 72.74,
#  '_id': ObjectId('63c556af17b2c42673cd4182'),
#  'index': 183}
# {'Al': 0.56,
#  'Ba': 0.0,
#  'Ca': 11.22,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.56,
#  'RI': 1.51969,
#  'Si': 73.48,
#  '_id': ObjectId('63c556af17b2c42673cd4183'),
#  'index': 184}
# {'Al': 0.34,
#  'Ba': 0.0,
#  'Ca': 6.65,
#  'Class': 6,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 17.38,
#  'RI': 1.51115,
#  'Si': 75.41,
#  '_id': ObjectId('63c556af17b2c42673cd4184'),
#  'index': 185}
# {'Al': 1.81,
#  'Ba': 1.19,
#  'Ca': 5.43,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 1.76,
#  'Mg': 3.2,
#  'Na': 13.69,
#  'RI': 1.51131,
#  'Si': 72.81,
#  '_id': ObjectId('63c556af17b2c42673cd4185'),
#  'index': 186}
# {'Al': 2.22,
#  'Ba': 1.63,
#  'Ca': 5.79,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 1.46,
#  'Mg': 3.26,
#  'Na': 14.32,
#  'RI': 1.5183799999999998,
#  'Si': 71.25,
#  '_id': ObjectId('63c556af17b2c42673cd4186'),
#  'index': 187}
# {'Al': 1.23,
#  'Ba': 0.0,
#  'Ca': 8.83,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.6,
#  'Mg': 3.34,
#  'Na': 13.44,
#  'RI': 1.52315,
#  'Si': 72.38,
#  '_id': ObjectId('63c556af17b2c42673cd4187'),
#  'index': 188}
# {'Al': 2.06,
#  'Ba': 0.0,
#  'Ca': 9.76,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.76,
#  'Mg': 2.2,
#  'Na': 14.86,
#  'RI': 1.52247,
#  'Si': 70.26,
#  '_id': ObjectId('63c556af17b2c42673cd4188'),
#  'index': 189}
# {'Al': 1.31,
#  'Ba': 1.68,
#  'Ca': 8.61,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.31,
#  'Mg': 1.83,
#  'Na': 15.79,
#  'RI': 1.52365,
#  'Si': 70.43,
#  '_id': ObjectId('63c556af17b2c42673cd4189'),
#  'index': 190}
# {'Al': 1.79,
#  'Ba': 0.76,
#  'Ca': 8.67,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 1.78,
#  'Na': 13.88,
#  'RI': 1.51613,
#  'Si': 73.1,
#  '_id': ObjectId('63c556af17b2c42673cd418a'),
#  'index': 191}
# {'Al': 2.38,
#  'Ba': 0.64,
#  'Ca': 8.76,
#  'Class': 7,
#  'Fe': 0.09,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.85,
#  'RI': 1.5160200000000001,
#  'Si': 73.28,
#  '_id': ObjectId('63c556af17b2c42673cd418b'),
#  'index': 192}
# {'Al': 2.79,
#  'Ba': 0.4,
#  'Ca': 9.04,
#  'Class': 7,
#  'Fe': 0.09,
#  'K': 0.04,
#  'Mg': 0.0,
#  'Na': 14.2,
#  'RI': 1.51623,
#  'Si': 73.46,
#  '_id': ObjectId('63c556af17b2c42673cd418c'),
#  'index': 193}
# {'Al': 2.0,
#  'Ba': 1.59,
#  'Ca': 8.53,
#  'Class': 7,
#  'Fe': 0.08,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.75,
#  'RI': 1.51719,
#  'Si': 73.02,
#  '_id': ObjectId('63c556af17b2c42673cd418d'),
#  'index': 194}
# {'Al': 1.98,
#  'Ba': 1.57,
#  'Ca': 8.52,
#  'Class': 7,
#  'Fe': 0.07,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.56,
#  'RI': 1.51683,
#  'Si': 73.29,
#  '_id': ObjectId('63c556af17b2c42673cd418e'),
#  'index': 195}
# {'Al': 2.68,
#  'Ba': 0.61,
#  'Ca': 9.07,
#  'Class': 7,
#  'Fe': 0.05,
#  'K': 0.08,
#  'Mg': 0.0,
#  'Na': 14.14,
#  'RI': 1.51545,
#  'Si': 73.39,
#  '_id': ObjectId('63c556af17b2c42673cd418f'),
#  'index': 196}
# {'Al': 2.54,
#  'Ba': 0.81,
#  'Ca': 9.41,
#  'Class': 7,
#  'Fe': 0.01,
#  'K': 0.14,
#  'Mg': 0.0,
#  'Na': 13.87,
#  'RI': 1.51556,
#  'Si': 73.23,
#  '_id': ObjectId('63c556af17b2c42673cd4190'),
#  'index': 197}
# {'Al': 2.34,
#  'Ba': 0.66,
#  'Ca': 8.95,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.7,
#  'RI': 1.5172700000000001,
#  'Si': 73.28,
#  '_id': ObjectId('63c556af17b2c42673cd4191'),
#  'index': 198}
# {'Al': 2.66,
#  'Ba': 0.64,
#  'Ca': 9.08,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.04,
#  'Mg': 0.0,
#  'Na': 14.38,
#  'RI': 1.51531,
#  'Si': 73.1,
#  '_id': ObjectId('63c556af17b2c42673cd4192'),
#  'index': 199}
# {'Al': 2.51,
#  'Ba': 0.53,
#  'Ca': 8.83,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.05,
#  'Mg': 0.0,
#  'Na': 15.01,
#  'RI': 1.51609,
#  'Si': 73.05,
#  '_id': ObjectId('63c556af17b2c42673cd4193'),
#  'index': 200}
# {'Al': 2.25,
#  'Ba': 0.63,
#  'Ca': 8.34,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 15.15,
#  'RI': 1.51508,
#  'Si': 73.5,
#  '_id': ObjectId('63c556af17b2c42673cd4194'),
#  'index': 201}
# {'Al': 1.19,
#  'Ba': 0.0,
#  'Ca': 8.93,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 2.7,
#  'Mg': 0.0,
#  'Na': 11.95,
#  'RI': 1.51653,
#  'Si': 75.18,
#  '_id': ObjectId('63c556af17b2c42673cd4195'),
#  'index': 202}
# {'Al': 2.42,
#  'Ba': 0.56,
#  'Ca': 8.39,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.85,
#  'RI': 1.51514,
#  'Si': 73.72,
#  '_id': ObjectId('63c556af17b2c42673cd4196'),
#  'index': 203}
# {'Al': 1.99,
#  'Ba': 1.71,
#  'Ca': 8.28,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.8,
#  'RI': 1.5165799999999998,
#  'Si': 73.11,
#  '_id': ObjectId('63c556af17b2c42673cd4197'),
#  'index': 204}
# {'Al': 2.27,
#  'Ba': 0.67,
#  'Ca': 8.71,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.95,
#  'RI': 1.51617,
#  'Si': 73.3,
#  '_id': ObjectId('63c556af17b2c42673cd4198'),
#  'index': 205}
# {'Al': 1.8,
#  'Ba': 1.55,
#  'Ca': 8.61,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.95,
#  'RI': 1.51732,
#  'Si': 72.99,
#  '_id': ObjectId('63c556af17b2c42673cd4199'),
#  'index': 206}
# {'Al': 1.87,
#  'Ba': 1.38,
#  'Ca': 8.67,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.94,
#  'RI': 1.51645,
#  'Si': 73.11,
#  '_id': ObjectId('63c556af17b2c42673cd419a'),
#  'index': 207}
# {'Al': 1.82,
#  'Ba': 2.88,
#  'Ca': 6.47,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 1.41,
#  'Mg': 0.0,
#  'Na': 14.39,
#  'RI': 1.51831,
#  'Si': 72.86,
#  '_id': ObjectId('63c556af17b2c42673cd419b'),
#  'index': 208}
# {'Al': 2.74,
#  'Ba': 0.54,
#  'Ca': 9.45,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.37,
#  'RI': 1.5164,
#  'Si': 72.85,
#  '_id': ObjectId('63c556af17b2c42673cd419c'),
#  'index': 209}
# {'Al': 2.88,
#  'Ba': 1.06,
#  'Ca': 9.18,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.08,
#  'Mg': 0.0,
#  'Na': 14.14,
#  'RI': 1.51623,
#  'Si': 72.61,
#  '_id': ObjectId('63c556af17b2c42673cd419d'),
#  'index': 210}
# {'Al': 1.99,
#  'Ba': 1.59,
#  'Ca': 8.4,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.92,
#  'RI': 1.51685,
#  'Si': 73.06,
#  '_id': ObjectId('63c556af17b2c42673cd419e'),
#  'index': 211}
# {'Al': 2.02,
#  'Ba': 1.64,
#  'Ca': 8.44,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.36,
#  'RI': 1.52065,
#  'Si': 73.42,
#  '_id': ObjectId('63c556af17b2c42673cd419f'),
#  'index': 212}
# {'Al': 1.94,
#  'Ba': 1.57,
#  'Ca': 8.48,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.38,
#  'RI': 1.51651,
#  'Si': 73.61,
#  '_id': ObjectId('63c556af17b2c42673cd41a0'),
#  'index': 213}
# {'Al': 2.08,
#  'Ba': 1.67,
#  'Ca': 8.62,
#  'Class': 7,
#  'Fe': 0.0,
#  'K': 0.0,
#  'Mg': 0.0,
#  'Na': 14.23,
#  'RI': 1.51711,
#  'Si': 73.36,
#  '_id': ObjectId('63c556af17b2c42673cd41a1'),
#  'index': 214}
